# %%
import socket
import sys
import requests
import requests_oauthlib
import json

# %%
# Replace the values below with yours
ACCESS_TOKEN = '1048005627816169473-5tJdLYafXOfCUaHWDFtcqjCvBRdU90'
ACCESS_SECRET = 'iIQRVbZTN625Zn1xRPwDKkOH8Mk4xqrAEn8ICb39CTIeY'
CONSUMER_KEY = 'iTrUDoKffZNLfSYvc9ctDXGJZ'
CONSUMER_SECRET = 'XEuXkw8AesuyxYaiPG7CSI1r0IhuXhcN8vvTYyimrCoAvMShU4'
my_auth = requests_oauthlib.OAuth1(CONSUMER_KEY, CONSUMER_SECRET,ACCESS_TOKEN, ACCESS_SECRET)

# %%
def get_tweets():
    url = 'https://stream.twitter.com/1.1/statuses/filter.json'
    query_data = [('language', 'en'), ('locations', '-130,-20,100,50'),('track','#')]
    query_url = url + '?' + '&'.join([str(t[0]) + '=' + str(t[1]) for t in query_data])
    response = requests.get(query_url, auth=my_auth, stream=True)
    print(query_url, response)
    return response

# %%
def send_tweets_to_spark(http_resp, tcp_connection):
    for line in http_resp.iter_lines():
        try:
            full_tweet = json.loads(line)
            tweet_text = full_tweet['text']
            print("Tweet Text: " + tweet_text)
            print ("------------------------------------------")
            tcp_connection.send(tweet_text + '\n')
        except:
            e = sys.exc_info()[0]
            print("Error: %s" % e)

# %%
TCP_IP = "localhost"
TCP_PORT = 9009
conn = None
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((TCP_IP, TCP_PORT))

# %%
s.listen(1)
print("Waiting for TCP connection...")
conn, addr = s.accept()
print("Connected... Starting getting tweets.")
resp = get_tweets()
# send_tweets_to_spark(resp, conn)


http_resp = resp
tcp_connection = conn
for line in http_resp.iter_lines():
    try:
        full_tweet = json.loads(line)
        tweet_text = full_tweet['text']
        print("Tweet Text: " + tweet_text)
        print ("------------------------------------------")
        tweet_text += '\n'
        tcp_connection.send(tweet_text.encode())
    except:
        e = sys.exc_info()
        print("Raise an Error:")
        print(e)
# Out:
# Waiting for TCP connection...
# Connected... Starting getting tweets.
# https://stream.twitter.com/1.1/statuses/filter.json?language=en&locations=-130,-20,100,50&track=# <Response [200]>
# Tweet Text: Irritated asffff !
# ------------------------------------------
# Tweet Text: @Deadspin Confused fan wearing https://t.co/fFJZZ8M83c
# ------------------------------------------
# Tweet Text: And S. Rashid is an invader...???
# ------------------------------------------
# Tweet Text: @S_morales77 @DraftKings My lineup this week looks good, so if I don’t win money I never will lol
# ------------------------------------------
# Tweet Text: Party at Timmy’s!
# ------------------------------------------
# Tweet Text: This QT in KC has gas bays on BOTH SIDES😱 https://t.co/M2vawXE4mP
# ------------------------------------------
# Tweet Text: ❤you Dino!
# ------------------------------------------
# Tweet Text: Right?!?!?!
# ------------------------------------------
# Tweet Text: @BoSnerdley Chris Wallace can go
# ------------------------------------------
# Tweet Text: UNT did it first
# ------------------------------------------
# Tweet Text: Another homecoming in the books ❤️ it was a great day!! #ekucolonels https://t.co/K6RX0Yb0c2
# ------------------------------------------
# Tweet Text: Bullshit.
# ------------------------------------------
# Tweet Text: can we talk about how i really think im dying
# ------------------------------------------
# Tweet Text: @WesleyLowery @sainttoad Wesley - While I'm agree that elected officials are subject to criticism without regard to… https://t.co/fxqSntURsz
# ------------------------------------------
# Tweet Text: it’s such an amazing feeling to help out w/ a wonderful group of girls &amp; to see their reactions when they place in finals 😍🎉
# ------------------------------------------
# Tweet Text: @RoundRockTim That’s already been discussed in this thread. Sexist and the fact that the team is now defunct.  Denied!
# ------------------------------------------
# Tweet Text: BREAKING: The #Bulls waive C Omar Asik.
# ------------------------------------------
# Tweet Text: WAN BISSAKA now just throw £35m at Palace @ChelseaFC
# ------------------------------------------
# Tweet Text: First day 💪🏼💪🏼💛 (@ Body Masters in Jeddah, Makkah) https://t.co/jKuFuC8B9b
# ------------------------------------------
# Tweet Text: light intensity shower rain -&gt; light intensity drizzle
# temperature up 62°F -&gt; 64°F
# humidity down 82% -&gt; 60%
# wind 6mph -&gt; 8mph
# ------------------------------------------
# Tweet Text: @Dan_Cassaro @fanelli @okpants Reminds me about the good ol bible verse about the wise man who built his house of c… https://t.co/Jk92NI7VFn
# ------------------------------------------
# Tweet Text: You are proud?  That is unbelievable.  You should be ashamed of what your "administration" has accomplished.  You a… https://t.co/S8EE4gLKz4
# ------------------------------------------
# Tweet Text: The cliche would lead me to believe that a comic left on my seat is gonna teach me about Jesus and sin at the end. https://t.co/ty1z4HouzJ
# ------------------------------------------
# Tweet Text: I think a lot of NFL coaches think, "an option heavy package at the goal line for our mobile QB? Nah... they'll be expecting that."
# ------------------------------------------
# Tweet Text: Kyle Dake is a super hero I swear.
# ------------------------------------------
# Tweet Text: @myronmom_ This took me out https://t.co/azYk7NdnyQ
# ------------------------------------------
# Tweet Text: @Reuters How can killing be a mistake! It was preplanned &amp; authorized by MBS. He must answer to the world.
# ------------------------------------------
# Tweet Text: He would’ve created a PP goal for us on at least 2 of our PP’s but okay keep going on with your complete nonsense
# ------------------------------------------
# Tweet Text: @LauraLoomer @MichaelAvenatti @keithellison I think you look quite tasty
# ------------------------------------------
# Tweet Text: @kenolin1 I can’t retweet this. It’s so wrong. These are intelligent civilized animals. Sick.
# ------------------------------------------
# Tweet Text: @PaolaGonzalezzz @AmericanAir I’m good now, but sheesh I’ve never had a panic attack on a flight. But today was that day.
# ------------------------------------------
# Tweet Text: Always learn to love yourself before loving others #selflove is always the best love ❤️ #blessings
# ------------------------------------------
# Tweet Text: @shawnemerriman You still the man!
# ------------------------------------------
# Tweet Text: Congrats to @natalieymoore on receiving an Honorary Doctor of Psychology Degree from @AdlerUniversity.
# ------------------------------------------
# Tweet Text: Came back to a clean room..💕
# ------------------------------------------
# Tweet Text: I thought the same thing while watching this yesterday!!! 😂
# ------------------------------------------
# Tweet Text: Interested in a #job in #Derby, KS? This could be a great fit: https://t.co/0BEky7KmYE #SupplyChain #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Join the Kelly Services team! See our latest #job opening here: https://t.co/BkGoT8zOgc #KellyJobs #KellyServices… https://t.co/Mzq1QbFc8J
# ------------------------------------------
# Tweet Text: This #job might be a great fit for you: Senior Project Manager - Services SSA - https://t.co/SJyhh6UcFo… https://t.co/iLLAxicSOE
# ------------------------------------------
# Tweet Text: We're #hiring! Read about our latest #job opening here: Patient Care Technician Preceptor - PCT -… https://t.co/Ob83ek1SGu
# ------------------------------------------
# Tweet Text: Want to work in #Stowe, VT? View our latest opening: https://t.co/hFVHeTd79V #Banking #Job #Jobs #Hiring #CareerArc
# ------------------------------------------
# Tweet Text:
Hiring #CareerArc
# ------------------------------------------
# Tweet Text: See our latest #Hickory, NC #job and click to apply: Fiber to the Home Design Engineer (FTTH) -… https://t.co/Ya6o54DMOP
# ------------------------------------------
# Raise an Error:
# (<class 'KeyError'>, KeyError('text',), <traceback object at 0x7f4dab889a48>)
# Tweet Text: @holycowcollect They could have tied game they went for 2 got zip
# 20/19 chargers
# ------------------------------------------
# Tweet Text: Once I’m outta denton I’m not coming back
# ------------------------------------------
# Tweet Text: @Seattie @DeepStateShu @tedcruz @DevinNunes @SteveKingIA @DanaRohrabacher @OrrinHatch Oh well hell, the hexes I put… https://t.co/MVgO4Wembu
# ------------------------------------------
# Tweet Text: If you're looking for work in Florence, SC, check out this #job: https://t.co/ZzQtkBM6kC #GeneralScience #CareerArc
# ------------------------------------------
# Tweet Text: Please don’t be that annoying person that questions something I say just bc it is/it’s not on my Snapchat 🤦🏻‍♂️ I d… https://t.co/lV9yDnXbPG
# ------------------------------------------
# Tweet Text: @Monica_ion English Bulldog!
# ------------------------------------------
# Tweet Text: We're #hiring! Read about our latest #job opening here: Laborer (seasonal) - https://t.co/mujSQUDEgH #SupplyChain #Waverly, IL #CareerArc
# ------------------------------------------
# Raise an Error:
# (<class 'KeyError'>, KeyError('text',), <traceback object at 0x7f4dab88e748>)
# Tweet Text: @JacobAWohl Keep digging Michael!
#
# Wait you hit bottom and had your jump the shark moment a year ago.
#
# #MAGA
# ------------------------------------------
# Tweet Text: We just drove 2,000 miles in 2 1/2 days to perform in Vancouver, and make it back in time to keep freeflying!
# .
# .… https://t.co/Kp8sXxvjLd
# ------------------------------------------
# Tweet Text: Russia helped you cheat to win!
#
# Real winners never resort to cheating and lying.
# Losers do!
#
# You, your family and… https://t.co/gu5BjIvCz4
# ------------------------------------------
# Tweet Text: @PanthersSource @JourdanRodrigue Elder can be a really good player for us. Showed in preseason. I really don’t like… https://t.co/S6zSEAzcxM
# ------------------------------------------
# Tweet Text: If you can’t hold my name in good graces outside of my presence you do not deserve anything from me ✌🏾
# ------------------------------------------
# Tweet Text: #USGS08066000 - Trinity Rv at Riverside, TX
# Height: 135.7ft ▼ (133.5ft)
# Flow: N/Acfs
# https://t.co/ChqsJ6KZ23
# ------------------------------------------
# Tweet Text: OMG anyone else want to wake up one day at just look like @lauralittle7? Bc same. 🙃 She ROCKED rocked in one of our… https://t.co/R4t0LxfTEQ
# ------------------------------------------
# Tweet Text: Can you recommend anyone for this #job? Summer 2019 Technical Internship Program - https://t.co/pm3gcumdn2… https://t.co/deVypIagvk
# ------------------------------------------
# Tweet Text: @lamonikitty I slept over your place last night 💃🏻
# ------------------------------------------
# Tweet Text: Want to work in #Huntington, WV? View our latest opening: https://t.co/IKQT7hPBCh #Inventory #Retail #Job #Jobs #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: I guess when you’re 10, you think you are hungrier then you actually are.
# 😳
# Pretty doubtful this will be conquered… https://t.co/UDOCGJjhXM
# ------------------------------------------
# Tweet Text: Can you recommend anyone for this #job in #Northville, MI? https://t.co/gkBIoolldE #KellyJobs #KellyServices #Recruiting #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: i’m in blue/white with a *tiny swatch of red and everyone thinks i’m a Bills fN...
# ------------------------------------------
# Tweet Text: You’re literally the best! I’ll be home soon baby😭
# ------------------------------------------
# Tweet Text: Can you recommend anyone for this #job in #Danville, IL? https://t.co/e1yKFFYp3X #Pharmaceutical #Hiring #CareerArc
# ------------------------------------------
# Tweet Text:
Hiring #CareerArc
# ------------------------------------------
# Tweet Text: @mor10 I feel like autumn leaves are a perfect example of the benefits of procrastination, up until it the time it rains on them.
# ------------------------------------------
# Tweet Text: Want to work at Remedy Intelligent Staffing? We're #hiring in #Papillion, NE! Click for details:… https://t.co/zjrzzpx6jG
# ------------------------------------------
# Tweet Text: #USGS08088000 - Brazos Rv nr South Bend, TX
# Height: 24.5ft ▲ (21ft)
# Flow: 18300cfs
# https://t.co/BssXiBMRSi
# ------------------------------------------
# Tweet Text: i need a new group of friends.....preferably about 4 people who likes to go on trips, adventures, just do fun shit etc. 👀
# ------------------------------------------
# Tweet Text: Join the Rogers team! See our latest #job opening here: https://t.co/oiFD2KxfoR #ElectricianJobs #Irving, TX #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: After a successful #ecodistrictssummit18 we headed to #railvolution #PGH for an intro course to the… https://t.co/BP1l7z9lKU
# ------------------------------------------
# Tweet Text: Join the Allied Universal team! See our latest #job opening here: https://t.co/v5M39L7cLc #security #LittleRock, AR #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Drop by and say hi.  11AM - 1PM. Bring your fishing rod.
#  #realestate #forsale #realtor #realestatetips… https://t.co/yVcfn4VutE
# ------------------------------------------
# Tweet Text: Ohhh yes
# ------------------------------------------
# Tweet Text: Get him a better brain 🧠
# ------------------------------------------
# Tweet Text: This #job might be a great fit for you: Welder - https://t.co/oz4SentqUo #Construction #Oshkosh, WI #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Music night
# Event managment
# sound &amp;SMD has been cleared. https://t.co/Fc1HfEMljT
# ------------------------------------------
# Tweet Text: Can you recommend anyone for this #job? Center Standards Officer - https://t.co/gMO5BTs9Wm #corrections #Morganfield, KY #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Literally every time i take colt somewhere, grown men bark at him. Like why.....
# ------------------------------------------
# Tweet Text: I look forward to the inevitable @puptheband, @frankturner, @arkellsmusic arena tour.
# ------------------------------------------
# Tweet Text: See our latest #Hinesville, GA #job and click to apply: Network Administrator - https://t.co/Ema5mqLuLQ #IT #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: We're #hiring! Click to apply: Quality Technician - https://t.co/gKvK5CZ2Sh #SkilledTrade Columbia, MO #Job #Jobs #CareerArc
# ------------------------------------------
# Tweet Text: A Big Shift Is Coming, and It Could Uber-ize Entire Industries https://t.co/xy0mOqO6ts via @singularityhub
# ------------------------------------------
# Tweet Text: See our latest #Monticello, MS #job and click to apply: Emergency Medicine - EM Physician - https://t.co/73sUurZ9GP… https://t.co/l4rJr33JT2
# ------------------------------------------
# Tweet Text: I'm at Tahlia St &amp; Madina Rd Intersection in Jeddah, Makkah Province https://t.co/8xMlFrk7OZ
# ------------------------------------------
# Raise an Error:
# (<class 'KeyError'>, KeyError('text',), <traceback object at 0x7f4dab645e08>)
# Tweet Text: I miss my modi @_thursday
# ------------------------------------------
# Raise an Error:
# (<class 'KeyError'>, KeyError('text',), <traceback object at 0x7f4dab645348>)
# Tweet Text: good morning, if your crush eats chips for breakfast then let em’ know they’ve been disavowed
# ------------------------------------------
Hiring #CareerArc
# ------------------------------------------
# Tweet Text: If you heard something bout me , go hear that shit again IDGAF 😂🖕🏾
# ------------------------------------------
# Tweet Text: Republicans lie about fraud while they swindling millions of people out of healthcare, their entitlements and their… https://t.co/blXiHzKWIv
# ------------------------------------------
# Tweet Text: It’s starting to feel like you’re still here with me maxanish ❤️
# .
# .
# .
# .
# .
# .
# .
# #art #artist #fineart… https://t.co/zvdDxhFY0N
# ------------------------------------------
# Tweet Text: I'm at @CAEOxfordATC in Dammam, Ash Sharqiyah https://t.co/dVmAibvgsQ
# ------------------------------------------
# Tweet Text: @DearAuntCrabby Me too! I now block all i come across.
# ------------------------------------------
# Tweet Text: Slaying in Launch Event Party of  pubji_pb They gotta awesome music, drinks, food and interiors for both youth and… https://t.co/11zIVHgnPm
# ------------------------------------------
# Tweet Text: need about 12 cups of coffee rn
# ------------------------------------------
# Tweet Text: Extremely disappointed. I’ve always felt safe w CSPD around but not after watching that video &amp; reading this.
# ------------------------------------------
# Tweet Text: Sunday morning! #Pipopeland #RunningMan #RunningTime @ Paseo del Rio Atoyac https://t.co/GypI8wlVI5
# ------------------------------------------
# Tweet Text: @FactsProfessor Good
# ------------------------------------------
# Tweet Text: @HouseGOP @Heritage The reason why taxes are going up, programs are being defunded and deficits are increasing is t… https://t.co/rRE7tIHl4U
# ------------------------------------------
# Tweet Text: We're #hiring! Read about our latest #job opening here: Part Time Store Associate- CROSSROADS CENTER -… https://t.co/7GTZcdPQV5
# ------------------------------------------
# Tweet Text: And den somehow you turn into my girlfriend
# ------------------------------------------
# Tweet Text: See our latest #Albertville, AL #job and click to apply: Security Officer 7 AM - 3PM - Mon - Fri -… https://t.co/VHJ6SMeuPS
# ------------------------------------------
# Tweet Text: I made it to my twenties, now what’s the fun in that? 🤧🎉
# ------------------------------------------
# Tweet Text: This what the young athletes of Sacramento, California need. Go to @gamefitsac, you’ll see... @HBO @Showtime… https://t.co/6LP5XGWu9v
# ------------------------------------------
# Tweet Text: Listening to @MyFavMurder -difference between men/women- hubby goes to rest stop “this smells” I go in and “is a ki… https://t.co/oe5rF6Q0gS
# ------------------------------------------
# Tweet Text: Call me kiddo cause this what my panties gone always say unless I get plus sized then they gonna say “Lane Bryant” 😊
# ------------------------------------------
# Tweet Text: Join the Rexel Holdings USA team! See our latest #job opening here: https://t.co/wPgbBnNZql #SupplyChain #Nashville, TN #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: @dan_sinclair The Seattle NFC Championship game is a close second just because of the context and absurdity of that collapse
# ------------------------------------------
# Tweet Text: If only you knew someone at CNN.
# ------------------------------------------
# Tweet Text: Best food ever ❤️
# ------------------------------------------
# Tweet Text: Niggas out here eating ass.....sheesh 😬
# ------------------------------------------
# Tweet Text: @Dax_x98 Because they are as cold the a black out in Hell. They don't care about the children, or the People who ne… https://t.co/4Wzx8wmWd5
# ------------------------------------------
# Tweet Text: @_Sherpreme That’s right!
# ------------------------------------------
# Tweet Text: Current status https://t.co/s6sbAWzfbo
# ------------------------------------------
# Tweet Text: Today's goal was to finish the half marathon in under 1 hour and 50 minutes. But having never raced before I wasn't… https://t.co/GjsfK01ssv
# ------------------------------------------
# Tweet Text: @iAmJCotti agreed...  I dont apologize or make excuses for it.  Its always justified! lol
# ------------------------------------------
# Tweet Text: There’s always that outside chance that mechanicals could kick this title chase to #MexicoGP #F1
# ------------------------------------------
# Tweet Text: @macworld As a side note, there is no excuse for the new Watch Series 4 face to ONLY be available on Series 4. The… https://t.co/XyO7kG87y5
# ------------------------------------------
# Tweet Text: YALL BETTA STOP PLAYIN’. That’s walkin’ from Houston to LA. Y’all ain’t walkin’ that far for nobody, y’all don’t ev… https://t.co/TcvL62ze7V
# ------------------------------------------
# Tweet Text: @kaul_vivek You can explore "Peaky Blinders" if historic crime fiction interests you.
# ------------------------------------------
# Tweet Text: Come get groomed from head to toe here at Joe Black Barbershop where It’s Not Just A Haircut... It’s A Joe Black!… https://t.co/r5wMTkNO8F
# ------------------------------------------
# Tweet Text: Use the “Yes, and...” theory of improvisation. Build, build, build on ideas.
# ------------------------------------------
# Tweet Text: when I get drunk my dance moves go from conservative to full fledge stripper
# ------------------------------------------
# Tweet Text: @heyjacqui_ Think I might be a 3 only cuz I don't know what two are!
# ------------------------------------------
# Tweet Text: "It's a war zone, the metronome is the Morse code for the poor souls lost out in the cold cold." As introverted as… https://t.co/E8GTCI4w4h
# ------------------------------------------
# Tweet Text: @GregGutfeldShow @greggutfeld @drdrew @jimmyfailla @KatTimpf @PlanetTyrus @FoxNews If someone gives Stormy Daniels… https://t.co/nwSJQsczqg
# ------------------------------------------
# Tweet Text: Hey ummm guess what? This is my Twitter. NO ONE ON MY TIMELINE HAS A PROBLEM BUT SUM RANDO ASS BITCH FROM LA GOT SOMETHING TO SAY. 😂😂
# ------------------------------------------
# Tweet Text: The title track from our upcoming album is out on Spotify now! https://t.co/5b47Hk5OWC
# ------------------------------------------
# Tweet Text: Dying wish tonic/Odin is actually broken af
# ------------------------------------------
# Tweet Text: @_Gabrielfer Congratulations!
# ------------------------------------------
# Tweet Text: See I’m easy to please 🤷🏾‍♂️
# ------------------------------------------
# Tweet Text: Locals create tour for visitors to explore India's longest lake https://t.co/ZfKE3xqmTe via @lptravelnews
# ------------------------------------------
# Tweet Text: Got more love out here than I ever have even back in my own hometown😁
# ------------------------------------------
# Tweet Text: @Missgracetweets @escapesomewher1 All hail the orgasmic goddesses and mighty bedroom heroes of the world. 👐 https://t.co/qM5woqc7Cc
# ------------------------------------------
# Tweet Text: Join the Wells Fargo team! See our latest #job opening here: https://t.co/lEm3RhPp6F #InvestmentBanking Atlanta, GA #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: @lilyachty Top 2 &amp; he ain’t 2 🤷🏽‍♂️
# ------------------------------------------
# Tweet Text: Hood niggas they love me ⛑
# ------------------------------------------
# Tweet Text: Burritos from golden pride are disgusting. 🤢🤢
# ------------------------------------------
# Tweet Text: current weather in Wiesbaden: haze, 14°C
# 51% humidity, wind 3kmh, pressure 1026mb
# ------------------------------------------
# Tweet Text: @tinko_abby SEE MY GUYYYYYY ! https://t.co/FtKuP1Pbuf
# ------------------------------------------
# Tweet Text: 43r4r343r43r
# ------------------------------------------
# Tweet Text: That's the best news for today. @RanveerOfficial and @deepikapadukone, two of my most loved people in Bollywood, ar… https://t.co/he2fzBRzfI
# ------------------------------------------
# Tweet Text: fall break vibes ❄️ @ Burlington, Vermont https://t.co/XIUw3eeb17
# ------------------------------------------
# Tweet Text: so my dog bit me yesterday...still love him though🤷🏽‍♀️
# ------------------------------------------
# Tweet Text: andrew let it rip and then had to wear her pants
# ------------------------------------------
# Tweet Text: HOW TO LIVE A FOCUSED LIFE | TD JAKES 2018 | MOTIVATIONAL VIDEO https://t.co/I2YaCa2FZW via @YouTube
# ------------------------------------------
# Tweet Text: @DesignationSix @66Georgeny While I am happy the people of Kentucky seem to be paying attention now, they had the c… https://t.co/ylmsBf3Fg3
# ------------------------------------------
# Tweet Text: 6 people already tried it with me today and it’s only 9:40 AM. Its gonna be a long day 😴
# ------------------------------------------
# Tweet Text: @ddale8 Yes, because he's a carnival side show...He can't even spell constitution
# ------------------------------------------
# Tweet Text: I need blessings and my peace
# ------------------------------------------
# Tweet Text: @Sprongshow__ Preds only disappoint once a year. Tits, Vandy, Vols, Grizzlies disappoint all year long.
# ------------------------------------------
# Tweet Text: Me trying to fit in:
# ------------------------------------------
# Tweet Text: @purrlycat1 Block all communists this means u
# ------------------------------------------
# Tweet Text: As these receivers fail to step up, Delanie Walker’s absence is being felt more and more. #TENvsLAC
# ------------------------------------------
# Tweet Text: Happy Birthday Jenny #1803 #brunch @ 1803nyc https://t.co/x0GekmZpWy
# ------------------------------------------
# Tweet Text: @IPLPower Thank you so much to the awesome linemen for working diligently to restore our power! It’s finally back o… https://t.co/mYwjFFIlf7
# ------------------------------------------
# Tweet Text: I’m ready to go home for Thanksgivings now lol
# ------------------------------------------
# Tweet Text: @Jakehtbz awesome job at Toronto Marathon
# ------------------------------------------
# Tweet Text: Spoiler: I will.
# ------------------------------------------
# Tweet Text: Eric Garcetti just called the GOP Congress #BulliesBrownnosersandbunglers and it was good.
# ------------------------------------------
# Tweet Text: Today in starwars #StarWars #StarWarsHistory #ImperialScum #Foreverourprincess https://t.co/pzPs639dw6
# ------------------------------------------
# Tweet Text: @CheriJacobus Of course he is basing his claim on the FBI findings, led by Christopher Wray, a friend of Kavanaugh… https://t.co/uc9fI9tRkt
# ------------------------------------------
# Tweet Text: is Adrean Highschool an alternative school?! It looks like a little jail 😩
# ------------------------------------------
# Tweet Text: Locals create tour for visitors to explore India's longest lake https://t.co/ZfKE3xqmTe via @lptravelnews
# ------------------------------------------
# Tweet Text: @JayDobs78 @Topps I feel ya brother...I come home after buying 5 high # 1966 of 5 players I’ve never heard of for $… https://t.co/GEGbICUqHq
# ------------------------------------------
# Tweet Text: @TheBrandiRhodes I am wearing my Mrs. Nightmare hoodie. :)
# ------------------------------------------
# Tweet Text: @8NewsNow @DeanHeller Senator spineless!! Not getting MY VOTE!! You and Trump aren't worth it!!
# ------------------------------------------
# Tweet Text: Told y’all
# ------------------------------------------
# Tweet Text: Yeah, homecoming won last night 😂🤦🏾‍♀️
# ------------------------------------------
# Tweet Text: @SiriusXMFantasy hi! Need 2 out of these: Crowell, McCoy, Chubb, McCaffrey, Johnson. Thanks!
# ------------------------------------------
# Tweet Text: @TheKostos Classic mis read by Giants .org on Eli- he’s done
# ------------------------------------------
# Tweet Text: @ibrahim__kaita Put your eyes down!
# ------------------------------------------
# Tweet Text: So the big topic at the station dinner table today is the fight from last night since we have a lakers fan in here haha #HmfTown
# ------------------------------------------
# Tweet Text: Too soon? #brawlstStaplescenter @get_dizzy https://t.co/4irQpHSdk0
# ------------------------------------------
# Tweet Text: @violetsaucy I use to work at Panera 😂 wasa manager I can get you the hook up , and dick shit you know
# ------------------------------------------
# Tweet Text: 34r43r344r34r3
# ------------------------------------------
# Tweet Text: Game Day boys!!! Let’s eat ⚜️ @Saints
# ------------------------------------------
# Tweet Text: @chastitywolfe Thank you Chas 💚
# ------------------------------------------
# Tweet Text: I saw Mayfield looking good last night too. #UTSA
# ------------------------------------------
# Tweet Text: See our latest #Hinesville, GA #job and click to apply: Network Administrator - https://t.co/Ema5mqLuLQ #IT #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: At Follett, our Associates are the heart of our business! Interested in a #SupplyChain opportunity? Join our team a… https://t.co/tznHccYh87
# ------------------------------------------
# Tweet Text: Check check. Just making sure you have a Twitter @CoachVrabel50
# ------------------------------------------
# Tweet Text: @WillisHarris12 @DTRuot325 @dsizzle_07 Give it to him tho https://t.co/rsIgBMK4Iu
# ------------------------------------------
# Tweet Text: @marklutchman Your not alone I want someone who reads the Bible ✝📖 and follows the Bible.
# ------------------------------------------
# Tweet Text: Sorry but getting absolutely steamrolled by us every year isn't going to make this a rivalry. Ever. CSU is a second… https://t.co/LJVYD7Fag0
# ------------------------------------------
# Tweet Text: There is more to the story: in part, she's an eighth grader (just say'n)
# https://t.co/AUBZO9kvTd
# ------------------------------------------
# Tweet Text: We have work in many settings including clinics, home and schools. Choose one or choose them all. The one thing tha… https://t.co/eArfj7ygmM
# ------------------------------------------
# Tweet Text: The Mullah’s regime had entered the final phase of its role.The Iranian people are Ready for #Regimechange in #Iran… https://t.co/qNY24zp5o2
# ------------------------------------------
# Tweet Text: Maybe some cookies too. 🤔
# ------------------------------------------
# Tweet Text: 10, 9, 8, 7....2, 1 Dog The Bounty Hunter needs to return with a new show on a new network! #MillionOfFans are wait… https://t.co/aDNO5nLh8S
# ------------------------------------------
# Tweet Text: @20thcenturyfox give Dexter Fletcher the director credit @BoRhapMovie #BohemianRhapsody
# ------------------------------------------
# Tweet Text: @LordOfWalteria @axdeath @APHealthScience @AP @ClemsonUniv Read the Holy Bible bro.  You never see God with a lower case! #comeonman
# ------------------------------------------
# Tweet Text: @anadalayrojas_ It would have been better if you were there. You have helped Dima so much, you are awesome!
# ------------------------------------------
# Tweet Text: @alicekeeler Which problem will you give me when I come over?🤪🙏🏼
# ------------------------------------------
# Tweet Text: @tkrbaron Yo it was straight comedy
# ------------------------------------------
# Tweet Text: NCAACP has seen what's just for PR and not what's good for Yulín, that might be a good reason. Does that answer har… https://t.co/HoDyb9h4VU
# ------------------------------------------
# Tweet Text: @SenatorHeitkamp demand "Repeal Tax Cuts and Leave Health Care and Social Security Alone."
# ------------------------------------------
# Tweet Text: I love this
# ------------------------------------------
# Tweet Text: @Mazi_Osusu @asaapuchu @foodhubng__ @janiebanks Palli I no too know names of those places na... Where u dey sef? I dey The Planet
# ------------------------------------------
# Tweet Text: @PinkBelgium @surveyor_44 @realDonaldTrump Funders, Organizers, Leaders, of Illegals entering USA should be held responsible.
# ------------------------------------------
# Tweet Text: LETS GOOO! #BoltUp
# ------------------------------------------
# Tweet Text: Boss😂😂 eni3 we go detty wona bodies😂😂😂
# ------------------------------------------
# Tweet Text: @PeytonGCallanan It’s so good!
# ------------------------------------------
# Tweet Text: Why is it cheaper to buy a brand new printer opposed to buying ink for your current one
# ------------------------------------------
# Tweet Text: @AMike4761 The UN is a arm for terrorism. Get the UN out of America and America out of the UN.🇺🇸
# ------------------------------------------
# Tweet Text: 😊💜👪 @ Washington, District of Columbia https://t.co/QF0QBAAilD
# ------------------------------------------
# Tweet Text: Locals create tour for visitors to explore India's longest lake https://t.co/ZfKE3xqmTe via @lptravelnews
# ------------------------------------------
# Tweet Text: @emmaroller Really late to this, but I’m already sure it will be the highlight of my day tomorrow! I always missed it while on sabbatical.
# ------------------------------------------
# Tweet Text: @zigzagzachzoom @lizzy_sullivan A Scar Is Born*
# ------------------------------------------
# Tweet Text: Someone should’ve told me stitches get this itchy 🙄
# ------------------------------------------
# Tweet Text: @HeadDoctor15 Record it!
# ------------------------------------------
# Tweet Text: seen while running in LA: a guy on a skateboard playing the recorder.
# ------------------------------------------
# Tweet Text: @GetOnMy_ECHE7on So you liked this?
# ------------------------------------------
# Tweet Text: Breathe To Wellness donating 10% proceeds to Breast Cancer Patients &amp; Survivors.
# Book your Table or Chair massage,… https://t.co/LrxqiwXVcq
# ------------------------------------------
# Tweet Text: Call all Bills fans in Coachella Valley. Come out and join your new Bills Backers Chapter of Palm Desert. Colt vs B… https://t.co/cmkr61FvR9
# ------------------------------------------
# Tweet Text: @KenBath Thanks very much.
# ------------------------------------------
# Tweet Text: somebody brought up golden grahams this morning and I'm definitely gonna get me a big ass family box.
# ------------------------------------------
# Tweet Text: If there’s one thing I can’t stand it’s a liar
# ------------------------------------------
# Tweet Text: I charge $100 for faux and $110 for goddess locs I’m located in Atlanta *SERIOUS INQUIRES ONLY*
# ------------------------------------------
# Tweet Text: what time the second line start??
# ------------------------------------------
# Tweet Text: My friend John is buying NY Times and Iced Green Tea. (@ Starbucks in Chicago, IL w/ @golfskirun) https://t.co/QuNd1TmGrZ
# ------------------------------------------
# Tweet Text: @Clarissa_xplain @BeachesResorts Thanks Clarissa!! I’m going to miss these views!!
# ------------------------------------------
# Tweet Text: All of the Lakers western conference games will be just like last night
# ------------------------------------------
# Tweet Text: why is it always WESTCHESTER boys
# ------------------------------------------
# Tweet Text: @cozywan @gravyslavesTi Ain’t heard that name in a while, miss you essaaaa 🖖🏽🖖🏽🖖🏽
# ------------------------------------------
# Tweet Text: Im #Spartacus🙄 will be stepping down any day now....right?
# ------------------------------------------
# Tweet Text: @therealcliffyb Nice! I can't wait to see it!
# ------------------------------------------
# Tweet Text: Can I seriously find friends like this in SA? All my friends are boo’ed up. 😭
# ------------------------------------------
# Tweet Text: Good night God bless
# @ActorLeeMinHo #LeeMinHo #AlwaysWithLeeMinHo #promiz2014 #mymentertainment #weloveyouleeminho… https://t.co/26FpwOtHZw
# ------------------------------------------
# Tweet Text: @mattyglesias @JakeAnbinder don’t you mean JQA?
# ------------------------------------------
# Tweet Text: Ugh I love them💛
# ------------------------------------------
# Tweet Text: @CapeAir I’d really like to know why my 10am flight was “bumped” to 6pm.
# No one here seems to have a clue.
# ------------------------------------------
# Tweet Text: Bro Chris Paul got beef in LA like biggie did he fight every time 🤣🤣
# ------------------------------------------
# Tweet Text: The worst fucking allergies
# ------------------------------------------
# Tweet Text: I probably fractured my pinky last night. Oh fuck. What a weekend 😂
# ------------------------------------------
# Tweet Text: I miss my city #kcbornandraised 📍
# ------------------------------------------
# Tweet Text: @Eerie_Silverfox Thank you. :3
# ------------------------------------------
# Tweet Text: Who to start nonPPR?? #FF @FFXpertAdvice @FFScout @ffootballLIVE @ESPNFantasy @NFLfantasy @FantasyBeast15 @YahooFantasy @360FFB
# ------------------------------------------
# Tweet Text: 23 miles of almost all coasting to finish three days in Southern AZ. @ Mount Wrightson https://t.co/xQlSsZjCnS
# ------------------------------------------
# ...
# ------------------------------------------
# Tweet Text: it use to be hard for me to let go.
# ------------------------------------------
# Tweet Text: Weekday Picks (Oct 22-25): https://t.co/CdOwJK6bPZ #hblgigs @CoachAndLantern @nucountryspirit @MikeDaley8… https://t.co/jSXvO5ebPl
# ------------------------------------------
# Tweet Text: mimosa drunk @ brunch is my happy place
# ------------------------------------------
# Tweet Text: Check out this highlight!https://t.co/CNV78cp79b
# ------------------------------------------
# Tweet Text: Rondo clearly spit on him.
# ------------------------------------------
# Tweet Text: You think a sneeze is bad... you ever had to burp and couldn’t get it out? Feel like your chest about to explode.
# ------------------------------------------
# Tweet Text: Hey @HamillHimself, I just realized Lando coined "Alright Alright Alright" 13 years before @McConaughey. #EmpireStrikesBack
# ------------------------------------------
# Tweet Text: Here I go on this free Mexican labor early on a Sunday
# ------------------------------------------
# Tweet Text: Lmfao me and Karla
# ------------------------------------------
# Tweet Text: I don’t understand why Asians get mad at the “all Asians are smart” stereotype. Like it’s something negative 😂
# ------------------------------------------
# Tweet Text: Fruity
# ------------------------------------------
# Tweet Text: Delays - HARTFORD #I84 West at Exit 48 (SPRING ST) at 10/21/2018 12:49:50 PM #cttraffic
# ------------------------------------------
# Tweet Text: @Laxington_ happy birthday cuzzo !!!
# ------------------------------------------
# Tweet Text: Well damn...
# ------------------------------------------
# Tweet Text: Delays - HARTFORD #I84 West at Exit 48 (SPRING ST) at 10/21/2018 12:49:50 PM #cttraffic
# ------------------------------------------
# Tweet Text: Me never them, Me against the world lil bihhh &amp; yo azz chose the world 🌎 not the real king 🤴🏽 of Memphis
# ------------------------------------------
# Tweet Text: I'm at HYPE GYM in Qiblah https://t.co/8VENQ815WU
# ------------------------------------------
# Tweet Text: @DemBoyz_News 24-20 Cowboys
# ------------------------------------------
# Tweet Text: I’m ready for this weekend already🤣💯 I’m finnah be FUCKED UP 😂 the whole weekend ..
# ------------------------------------------
# Tweet Text: Spent Friday night riding the buddy seat of a friend's 8245R while he planted our wheat with a 40 air seeder.  I'm a bit jealous of his rig.
# ------------------------------------------
# Tweet Text: #currentmood From my home to yours, Happy Sunday 🎃 let the carving begin 🎃
# ________________________________________… https://t.co/3FW3B3SJ9Y
# ------------------------------------------
# Tweet Text: @yaelbok1 @bokeralmog You snooze - you lose 😏
# ------------------------------------------
# Tweet Text: @TMarie_10 @MedianPolitics @brianklaas Some dark money PAC of course.
# ------------------------------------------
# Tweet Text: Nathaniel Hawthorne is my favorite abuser of semicolons. 😆
# ------------------------------------------
# Tweet Text: "Bottoms up, and the devil laughs" gets me every time I see this💀
# ------------------------------------------
# Tweet Text: So obviously desperate.
# So desperately obvious.
# ------------------------------------------
# Tweet Text: Mamas don’t let your babies grow up to work sundaayyysss
# ------------------------------------------
# Tweet Text: Wrapping up the National Prison Doula Training with @DrShlafer talking about research and evaluation.… https://t.co/ad2GBUrsfW
# ------------------------------------------
# Tweet Text: Mood: https://t.co/uMmSTjRuIA
# ------------------------------------------
# Tweet Text: Wind 6,6 km/h WNW. Barometer 1023,5 hPa, Steady. Temperature 21,5 °C. Rain today 9,0 mm. Humidity 64%
# ------------------------------------------
# Tweet Text: this is an everyday thing for me
# ------------------------------------------
# Tweet Text: The Torch is always a stunner! 💫 @ Aspire Academy https://t.co/c3KKbrj7Gz
# ------------------------------------------
# Tweet Text: It feels so good outside. #SpookySZN
# ------------------------------------------
# Tweet Text: this look so good rn😭😍
# ------------------------------------------
# Tweet Text: May Allah’s rahamat be with him. Amin
# ------------------------------------------
# Tweet Text: I cant believe dude just went ghost on me 🤦🏾‍♂️ I guess finding a job aint gone be sweet as it was looking, I gotta stay motivated tho
# ------------------------------------------
# Tweet Text: rylo camera with a chesty mount on my way down Upper Predator at Tiger Mountain. It was a pain to haul a gimbal/GoP… https://t.co/l9d7wWLeVT
# ------------------------------------------
# Tweet Text: @InesElFjr Quand ??
# ------------------------------------------
# Tweet Text: @Bwa_Jay @Rockets_Insider @RedNationBlogga Lol on me!
# ------------------------------------------
# Tweet Text: Despite technical difficulties getting the live stream going last night, we did capture most of @jrastronomers set.… https://t.co/6S2x5I4hRZ
# ------------------------------------------
# Tweet Text: @Bobbybove16 Wallet and keys tops all
# ------------------------------------------
# Tweet Text: @JonGoeldner @NME I like Songs about Jane
# ------------------------------------------
# Tweet Text: You dont need to have the best season to talk a lil trash for the funs go giants
# ------------------------------------------
# Tweet Text: Your daily reminder why you need to vote republicans out of office in 15 days:
# ------------------------------------------
# Tweet Text: @ShannonMac @brothersosborne Saw them in Nashville last year - so good!!
# ------------------------------------------
# Tweet Text: I’m sorry but baby on board stickers are the stupidest thing I’ve ever seen on the back of a car
# ------------------------------------------
# Tweet Text: Just shows you we’re raised differently fam💯
# ------------------------------------------
# Tweet Text: My little brother woke me up to tell me he got a victory royale, I thought the house was on fire. 😞
# ------------------------------------------
# Tweet Text: This bitch @teylarmadesan  cracks me tf up g damn I love her fuck 😂😂😭😭😭😭😂😂😂😂😂😂
# ------------------------------------------
# Tweet Text: @BillyBorgz @hollyapfeiffer @krassenstein Oh bla bla bla.  Piss off, loser.
# ------------------------------------------
# Tweet Text: @RobertCDaily @ClayTravis Which is the only call that made sense
# ------------------------------------------
# Tweet Text: Anytime I see a American Medical Transportation vehicle I automatically rearrange the acronym to ATM. Not the ATM y… https://t.co/6KVv8KGE2w
# ------------------------------------------
# Tweet Text: @JohnIbbitson You should stop using the term leftists. I promise not to use the term fascist to refer to conservati… https://t.co/XTxYYr2Kbt
# ------------------------------------------
# Tweet Text: @LeftCross1st YIKES
# ------------------------------------------
# Tweet Text: What a waste of money. You’re right, truly hideous
# ------------------------------------------
# Tweet Text: We are being targeted like Hitler did bc sick ppl were not "IDEAL Arians". Govt is now practicing eugenics on pain… https://t.co/sKcTqHnjAJ
# ------------------------------------------
# Tweet Text: But let a nigga say this “he a hoe” or “he ain’t shit” fuck outta here
# ------------------------------------------
# Tweet Text: 🤣🔥 BURN IT ALL DOWN!! 🔥 🤣                                                         I Have 422 Friends Yet I Am lonel… https://t.co/TA6qMcdjwg
# ------------------------------------------
# Tweet Text: Beach? BBQ? Mann wassup
# ------------------------------------------
# Tweet Text: yall really don’t know me, I only show yall what I want yall to see 💯
# ------------------------------------------
# Tweet Text: 35 of y’all liked this AND AINT DM ME😑
# ------------------------------------------
# Tweet Text: perfect conditions for the 10k today. finished with a sub 5min/km and i'm super happy about it 😊💪 @ Rapperswil, Swi… https://t.co/sYJFE18GPX
# ------------------------------------------
# Tweet Text: @FearlessGirl24 @ggreenwald @Harryslaststand @AdamSchiff I am waiting to see WHICH USA lawmakers make moves for &amp; t… https://t.co/mbg8LYHT2a
# ------------------------------------------
# Tweet Text: @ta_Shepard I always loved football Sundays at Starbucks because we got some peace and quiet and I could clean. Unl… https://t.co/fxTHPk0M5a
# ------------------------------------------
# Tweet Text: @LowkeySesh have fun losing today https://t.co/Gd5tlhvYhI
# ------------------------------------------
# Tweet Text: Goals
# ------------------------------------------
# Tweet Text: Entertain All Of Them, Text All Of Them &amp; Fw All Of Them 😏💛🤞🏽
# ------------------------------------------
# Tweet Text: @cspr98 @russdiemon Awh why. Lol
# ------------------------------------------
# Tweet Text: Nigga Davon called us out on Snapchat cause he got drunk dab last night but was up at 7am sharp for church‼️😂
# ------------------------------------------
# Tweet Text: #KuruDanceFestival #kuru20 in august 2018 I attended the festival, the 2 day event brought together different Sesar… https://t.co/Bg00y2i6Vo
# ------------------------------------------
# Tweet Text: And just what in the hell would that be You idiot.”
# ------------------------------------------
# Tweet Text: @I_AM_Thugga Come let me serve you😄
# ------------------------------------------
# Tweet Text: AbigailG 01 in backdraw finals
#
# #ataresults
# ------------------------------------------
# Tweet Text: Weed, ball, rap.
# ------------------------------------------
# Tweet Text: LETS GOOOO PATRIOTS!!!!
# ------------------------------------------
# Tweet Text: how i look on the outside vs. how i feel on the inside https://t.co/HvFhVmjDnn
# ------------------------------------------
# Tweet Text: @Everton @CenkTosun_ No doubt he had one in his bag today!! Get in Tosun PAPA!! https://t.co/O730ju6TZl
# ------------------------------------------
# Tweet Text: Are you looking to follow a Premier League team? Are you also a #MNUFC fan? May I suggest following Crystal Palace.… https://t.co/dV6vu17NJl
# ------------------------------------------
# Tweet Text: @northside103 This to hard to pick lol
# ------------------------------------------
# Tweet Text: @mopenshaw @scottbraddock @BetoORourke @tedcruz Yea, but he didnt skateboard on stage. That's why. https://t.co/o03FSLhRaT
# ------------------------------------------
# Tweet Text: Try watch this video: #HowMuch remix by @AmgMedikal ft. @Paedeezy (@r2bees) x @sarkodie
# 👉👉https://t.co/2s5Lx8jlNl… https://t.co/CxN1DrQmYQ
# ------------------------------------------
# Tweet Text: Room with a view! #exprealty @ New Orleans, Louisiana https://t.co/BQydvZw6F6
# ------------------------------------------
# Tweet Text: @Xman_Bx @NavenduSingh_ Sure
# ------------------------------------------
# Tweet Text: It’s time to shave my legs.
# Will I? No.
# Do I care? No.
# ------------------------------------------
# Tweet Text: @JBBinLaden12 @Enzopalacio1 Even with the Celtics
# ------------------------------------------
# Tweet Text: Fav couple 💛
# ------------------------------------------
# Tweet Text: @JohnCleese But you do have to admit, there was also a lot of turnover due to the Inquisition...
# ------------------------------------------
# Tweet Text: @PressSec couldn’t happen to a nicer person.  It is never too late to change Sarah.  Dump’s reign will soon be over… https://t.co/SbFXF8M5GU
# ------------------------------------------
# Tweet Text: @siviyBrummie @WWENXT Haven’t had time to check out @NXTUK yet.
# ------------------------------------------
# Tweet Text: @Smashleyyymarie His FIRST miracle too!!!
# ------------------------------------------
# Tweet Text: Why does Black Lives Matter Atlanta keep promoting THE LGBTQ AGENDA, SEXUALITY &amp; GENDER? Folks when the cops pull y… https://t.co/9xFiltwMl4
# ------------------------------------------
# Tweet Text: This weekend was Border Bang 2, wish the awesome artwork done by my many hero’s of animation @mexopolis and his wif… https://t.co/hDyKqc7A3o
# ------------------------------------------
# Tweet Text: Lmfaooooooo
# ------------------------------------------
# Tweet Text: #ColtsNation: Who's ready for some #FOOTBALL🏈⁉️ https://t.co/zOloVtSNBg
# ------------------------------------------

# %%
ckey="iTrUDoKffZNLfSYvc9ctDXGJZ"
csecret="XEuXkw8AesuyxYaiPG7CSI1r0IhuXhcN8vvTYyimrCoAvMShU4"
atoken="1048005627816169473-5tJdLYafXOfCUaHWDFtcqjCvBRdU90"
asecret="iIQRVbZTN625Zn1xRPwDKkOH8Mk4xqrAEn8ICb39CTIeY"

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
class TweetsListener(StreamListener):
 
    def __init__(self, csocket):
        self.client_socket = csocket
 
    def on_data(self, data):
        try:
            print(data.split('\n'))
            self.client_socket.send(data)
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True




def sendData(c_socket):
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    twitter_stream = Stream(auth, TweetsListener(c_socket))
    twitter_stream.filter(track=['trump'])
    
    

s = socket.socket()     # Create a socket object
host = "127.0.0.1"      # Get local machine name
port = 5555      # Reserve a port for your service.
s.bind((host, port))    # Bind to the port

print("Listening on port: %s" % str(port))

s.listen(5)                 # Now wait for client connection.
c, addr = s.accept()        # Establish connection with client.

print( "Received request from: " + str( addr ) )

sendData( c )
