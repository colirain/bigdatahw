# %%
import socket
import sys
import requests
import requests_oauthlib
import json

# %%
# Replace the values below with yours
ACCESS_TOKEN = '1048005627816169473-5tJdLYafXOfCUaHWDFtcqjCvBRdU90'
ACCESS_SECRET = 'iIQRVbZTN625Zn1xRPwDKkOH8Mk4xqrAEn8ICb39CTIeY'
CONSUMER_KEY = 'iTrUDoKffZNLfSYvc9ctDXGJZ'
CONSUMER_SECRET = 'XEuXkw8AesuyxYaiPG7CSI1r0IhuXhcN8vvTYyimrCoAvMShU4'
my_auth = requests_oauthlib.OAuth1(CONSUMER_KEY, CONSUMER_SECRET,ACCESS_TOKEN, ACCESS_SECRET)

# %%
def get_tweets():
    url = 'https://stream.twitter.com/1.1/statuses/filter.json'
    query_data = [('language', 'en'), ('locations', '-130,-20,100,50'),('track','#')]
    query_url = url + '?' + '&'.join([str(t[0]) + '=' + str(t[1]) for t in query_data])
    response = requests.get(query_url, auth=my_auth, stream=True)
    print(query_url, response)
    return response

# %%
def send_tweets_to_spark(http_resp, tcp_connection):
    for line in http_resp.iter_lines():
        try:
            full_tweet = json.loads(line)
            tweet_text = full_tweet['text']
            print("Tweet Text: " + tweet_text)
            print ("------------------------------------------")
            tcp_connection.send(tweet_text + '\n')
        except:
            e = sys.exc_info()[0]
            print("Error: %s" % e)

# %%
TCP_IP = "localhost"
TCP_PORT = 9009
conn = None
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((TCP_IP, TCP_PORT))

# %%
s.listen(1)
print("Waiting for TCP connection...")
conn, addr = s.accept()
print("Connected... Starting getting tweets.")
resp = get_tweets()
# send_tweets_to_spark(resp, conn)


http_resp = resp
tcp_connection = conn
for line in http_resp.iter_lines():
    try:
        full_tweet = json.loads(line)
        tweet_text = full_tweet['text']
        print("Tweet Text: " + tweet_text)
        print ("------------------------------------------")
        tweet_text += '\n'
        tcp_connection.send(tweet_text.encode())
    except:
        e = sys.exc_info()
        print("Raise an Error:")
        print(e)
# Out:
# Waiting for TCP connection...
# Connected... Starting getting tweets.
# https://stream.twitter.com/1.1/statuses/filter.json?language=en&locations=-130,-20,100,50&track=# <Response [200]>
# Tweet Text: I made a bet that if the Astros lost last night I'd do the ol' handlebar. I did it 💀 https://t.co/1P2RJ3qr51
# ------------------------------------------
# Tweet Text: Spring Lake has tied it up off a fumble recovery; 17-17, 5:27 left in Q3. #SentPreps
# ------------------------------------------
# Tweet Text: I like this place! No wankers!!! @ Fayetteville, North Carolina https://t.co/1IJNPzQnfL
# ------------------------------------------
# Tweet Text: Watching #22July. #TeamNorway
# ------------------------------------------
# Tweet Text: @Olliesuperstar Shoot I forgot what I was gonna say🤦🏽‍♀️
# ------------------------------------------
# Tweet Text: Haunted house here I come😍🎃
# ------------------------------------------
# Tweet Text: Just posted a video @ Mi Rancho's Downtown, GA https://t.co/D8193Bh0Kh
# ------------------------------------------
# Tweet Text: Showered and oiled up. I got my fried Oreos and peach cobbler in bed wit me. 😍
# ------------------------------------------
# Tweet Text: Cedar Park brings the house and Chase Griffin takes advantage. His screen pass to Chux Nwabuko goes for a 33-yard t… https://t.co/pl5SgNemLl
# ------------------------------------------
# Tweet Text: @reedm @speakthelogos @patrickc It's both what prevents homelessness and obfuscates massive spending waste and inef… https://t.co/mDWZelIUwZ
# ------------------------------------------
# Tweet Text: people who hate me really make me laugh. they stay stalkin my social media. like yes stay in my business, im doing great yah creep hby?
# ------------------------------------------
# Tweet Text: @intheMatrixxx @DrZ4Congress @WMerthon @weartv @FOX10News @pnj @nytimes @nwfdailynews @maddow @CNN @WUWF… https://t.co/DiO9it4Nhx
# ------------------------------------------
# Tweet Text: I mean how is this baby so perfect. One more week until I get to love on her for a whole weekend. ❤️❤️ https://t.co/HnyfAh6bfi
# ------------------------------------------
# Tweet Text: Well worth it and I don’t fly that often
# ------------------------------------------
# Tweet Text: Caris LeVert just got T’d up. I’m extremely shook
# ------------------------------------------
# Tweet Text: FINALLY
# ------------------------------------------
# Tweet Text: After moving the ball down the field, Union county stalls out inside the Hornets 10, and the Tigers kicker misses a… https://t.co/AChcjniitQ
# ------------------------------------------
# Tweet Text: Morning chitchat:-
#
# Golden wishes for
# Golden people before
# Golden sun rays with
# Golden leaves on
# Golden day for
# Yo… https://t.co/8ATZFaFQqI
# ------------------------------------------
# Tweet Text: thank god for kid cudi during all the days i didnt have marijuana
# ------------------------------------------
# Tweet Text: Happy Homecoming Rams 🐑 #WSSUHomecoming
# ------------------------------------------
# Tweet Text: @Prince3eb
#
# Have you and hubby seen these? They are a hoot.
#
# Kirks nephew serves on the enterprise and is gay.
#
# https://t.co/1dlxPEGFxE
# ------------------------------------------
# Tweet Text: @AaronWorthing Nope I checked they said you Lie on Twitter. Thanks for the validation.
# ------------------------------------------
# Tweet Text: Transit Agencies: “Lets pay employees a competitive wage”
# GOP: “No that’s a waste of taxpayer money, find… https://t.co/4e7oikMt21
# ------------------------------------------
# Tweet Text: @LivePDNation From the 865 ... Knoxville Tennessee ... let’s do this K9 Friday
# ------------------------------------------
# Tweet Text: Won a free chicken sandwich from mickey Ds lol life is alright..
# ------------------------------------------
# Tweet Text: That kind of night. #954 https://t.co/EkNrlvgJkw
# ------------------------------------------
# Tweet Text: Star got so much damn drama
# ------------------------------------------
# Tweet Text: Just heard Bob Dylan say “booty call” in person
# ------------------------------------------
# Tweet Text: imma put that on my set
# ------------------------------------------
# Tweet Text: @davidaxelrod @MichelleHillie7 So they didn't stop hitting him until he was dead?
# ------------------------------------------
# Tweet Text: Tomorrow @xBattleclubpro
#
# #MANICEATER
# @TheMariaManic
# ------------------------------------------
# Tweet Text: Dunellen surprising Bound Brook in a Battle of Route 28.  Destroyers lead 9-0.  #njfootball
# ------------------------------------------
# Tweet Text: @KatyTurNBC Forgive him!
# ------------------------------------------
# Tweet Text: @frpaul1 @auxonic @MoggyBee @cfulgham @jonathanmcleod It's the only way!
# ------------------------------------------
# Tweet Text: @HorrorNights And not only that, Sunday is cheaper. 😞😭💔
# ------------------------------------------
# Tweet Text: @swydersk @Spencerjames211 @BrettCateley @TheLoneWolF_1 IFB
# #GainWithPetal ❤
# Thank you 💖 🌹
# ------------------------------------------
# Tweet Text: Whoaaa
# ------------------------------------------
# Tweet Text: Inbetween blessings rn 🙌🏽🙌🏽
# ------------------------------------------
# Tweet Text: #CapsCats will skate 4 on 4 for next 2:00
# ------------------------------------------
# Tweet Text: Accident. two right lanes blocked in #CarrolltonToLewisville on 35E NB at Corporate Dr, stop and go traffic back to FM 3040, delay of 3 mins
# ------------------------------------------
# Tweet Text: Why are Guatemalans always late 🤔
# ------------------------------------------
# Tweet Text: @travthroughlife @VillagesDE @knoxdaytripper @BarnetteJason @pubclub @StevenOnTheMove @RedParallax @RyanTravelsEats… https://t.co/uC2tVdMXPz
# ------------------------------------------
# Tweet Text: ... And a bear oh my
# ------------------------------------------
# Tweet Text: @caroljsroth So, did you purchase a ticket?
# ------------------------------------------
# Tweet Text: @foxandfriends @GeraldoRivera Don’t trust him
# ------------------------------------------
# Tweet Text: #SpiritNation you know the drill! You want the gift card to Harvey’s let us know where you are sitting and you coul… https://t.co/MJbzWmJuPr
# ------------------------------------------
# Tweet Text: Give leaves as butterflies a follow and add this to your playlist
# https://t.co/q5FJJ6mnO2
# ------------------------------------------
# Tweet Text: @DTone801 I’ll play
# ------------------------------------------
# Tweet Text: @afroSHIRL Sorry, but it was a video of a cat swiping them off, later reversed.
# ------------------------------------------
# Tweet Text: Set 1 Song 2 Jams are a thing now. Sweet.
# ------------------------------------------
# Tweet Text: I'm at Universidad Americana (UAM) in Cartago https://t.co/eqn4Gn2sPS
# ------------------------------------------
# Tweet Text: my head hurt so bad 😩
# ------------------------------------------
# Tweet Text: The commentary 😩
# ------------------------------------------
# Tweet Text: my night is fucking r u i n e d someone get me about 75 shots
# ------------------------------------------
# Tweet Text: Bout to try these https://t.co/5DXyNGzj2o
# ------------------------------------------
# Tweet Text: Need to boost your YouTube channel? Let’s work!
#
# Visit https://t.co/X0E2TZzKFA for pricing. https://t.co/jVzrzlp5CQ
# ------------------------------------------
# Tweet Text: @funder So they get the money in tax cuts and WHILE IN OFFICE!
# ------------------------------------------
# Tweet Text: Thanks to the @AmericanLegion Post88 for donating school supplies last week to our school and to @mcgavockele We lo… https://t.co/rXXofUwNHv
# ------------------------------------------
# Tweet Text: Accident cleared in #EastSide on I-10 Baytown E Fwy Inbound before The E Lp, stop and go traffic back to Normandy, delay of 10 mins #traffic
# ------------------------------------------
# Tweet Text: @maggielndnphoto @grooglesVISTA @ThisIsVISTA @jeterpenkins @ittybittyholly Jus a few shows, no tour for a while :)… https://t.co/w4ykrjauNm
# ------------------------------------------
# Tweet Text: She datin wolverine?
# ------------------------------------------
# Tweet Text: @Spencermusic1 tell this radio station to pick me i’ll give you a dollar https://t.co/LKW2mQmzbb
# ------------------------------------------
# Tweet Text: That nigga you stressing about fcking another bitch as we speak. Let it go sis 😩😭
# ------------------------------------------
# Tweet Text: I wanna do Halloween stuff with a big headed blonde girl for the rest of my life
# ------------------------------------------
# Tweet Text: @pjshelton_paula I don’t know if there’s a helicopter for that around here. They have always used planes and I thin… https://t.co/ev49iNZTCe
# ------------------------------------------
# Tweet Text: @LansingLugnuts Score?
# ------------------------------------------
# Tweet Text: how u ma family but speak reckless on my name? naah fuck yo love bitch 😭
# ------------------------------------------
# Tweet Text: K oomfs quote w something and i’ll record myself saying it.
# ------------------------------------------
# Tweet Text: @kinburnsheep @MdMcLean1 Good point.
# ------------------------------------------
# Tweet Text: At the Half Jasper 21 Harrison 6
# Jasper's ball to start the 2nd half
# ------------------------------------------
# Tweet Text: You do not have to be dying in order for me to kiss you.  You don’t even have to pay me.  It would just be an honor!
# ------------------------------------------
# Tweet Text: Give Kenny Atkinson a tech too please
# ------------------------------------------
# Tweet Text: @MeMeSyndrome_ @TAkeme2CHINA We argued with their ass on Twitter a while ago &amp; literally sent them maps their reply… https://t.co/WBG1TGp0oI
# ------------------------------------------
# Tweet Text: *me going to see halloween tonight*
# ------------------------------------------
# Tweet Text: 💀💀💀💀Fake news
# ------------------------------------------
# Tweet Text: “Football Friday” Toledo School for the Arts style. My feet aren’t frozen and these kids are SO amazing! @ Owens Co… https://t.co/8EviuQU2eg
# ------------------------------------------
# Tweet Text: @__iamLondon do I need to print this tix out if I bought it online
# ------------------------------------------
# Tweet Text: Drew your room ricky.alynn because I am obsessed ✨🌿.            •
# •
# •
# #gallerywalldecor #artoftheday… https://t.co/IMs61EPpzB
# ------------------------------------------
# Tweet Text: Someone’s getting a piece of ass tonight!!! 😂
# ------------------------------------------
# Tweet Text: weird flex but ok
# ------------------------------------------
# Tweet Text: You know you’re getting old when you’ve seen big 8 turn into food basket and into food king
# ------------------------------------------
# Tweet Text: @WhiteHouse #TrumpsDumb SMH 😔 @realDonaldTrump you are truly dumb and childish. You really need to listen to… https://t.co/Rm0wp8ESpC
# ------------------------------------------
# Tweet Text: Norman with 49-yard touchdown run, Dawson kick for 7-0 Pontiac lead over Rantoul after one period.🏈
# ------------------------------------------
# Tweet Text: @MrYeahIKnow My young boy @Terrell_Burden3 and I do a Workout on the morning of Every Saturday Evening Game, then w… https://t.co/ki015NSLbR
# ------------------------------------------
# Tweet Text: starting tomorrow i’m deleting everyone out my phone if someone text me ik where we stand at but right now i have u… https://t.co/uATdWB1E1R
# ------------------------------------------
# Tweet Text: @zedsdead No prayers. Dark side dub. Shut up and sing VIP.
# ------------------------------------------
# Tweet Text: As a parent I would of wanted all the smoke with everyone of those kids
# ------------------------------------------
# Tweet Text: HA HA HA those guys are fantastic
# ------------------------------------------
# Tweet Text: @askpanera Done
# ------------------------------------------
# Tweet Text: @AlyssaJAshton She looks great in this coat. And side note, are all the Middleton gals built like athletes? It’s incredible.
# ------------------------------------------
# Tweet Text: @SheISBeeaute_ @Only_OneLA Yes I can, I’m sure that her braids didn’t just slide out. They had an altercation that’… https://t.co/lSPfSGcqWv
# ------------------------------------------
# Tweet Text: @mattmilko What were they wearing?
# ------------------------------------------
# Tweet Text: @PressSec Suggest you ask the Saudis where the body is, or at least the parts.
# ------------------------------------------
# Tweet Text: Don’t save her
# She don’t wanna be saved
# ------------------------------------------
# Tweet Text: Bought
# ------------------------------------------
# Tweet Text: THIS AINT OT CHEIF
# ------------------------------------------
# Tweet Text: @Fuctupmind Oh yeah, we are Trump's Russian entourage.
# ------------------------------------------
# Tweet Text: Awwww right back atcha! 🤘🏻💗🤘🏻
# ------------------------------------------
# Tweet Text: @_Deplorable_Me @tedcruz @TXsen @BetoORourke Your Twitter account says you live in California. You don’t get to cho… https://t.co/Udvp0Sscyr
# ------------------------------------------
# Tweet Text: Couch seating at an arena❗️
#
# This may be the greatest idea in the history of the live sports experience 🤯
#
# Buying m… https://t.co/LooO7ZsIP8
# ------------------------------------------
# Tweet Text: Dardis darts his way to the 37 for a 1st down!
# ------------------------------------------
# Tweet Text: @LeStephism He’s so fetch 💁🏼‍♀️
# ------------------------------------------
# Tweet Text: TD Dawgs. Opelika 24 Stanhope Elmore 0 with 1:03 left in 1Q @hsscore @AL6AFootball @AHSAAUpdates @oanewspreps… https://t.co/rqfqIjsNke
# ------------------------------------------
# Tweet Text: @WrestlingAtomic @WWENXT @WWE @TripleH @StephMcMahon @FullSail I don't work for @WrestlingAtomic
# ------------------------------------------
# Tweet Text: @xforcades2 @Just_Bricy Dick move. Because nicotine is the only drug that, by you gasping for air, would make me wa… https://t.co/NagtyU4K8w
# ------------------------------------------
# Tweet Text: @ChrisWeinerUFC thats a non issue for me. However i wish servers were abit better and i wish we didnt have to pay t… https://t.co/ydqHzg1EID
# ------------------------------------------
# Tweet Text: A headline for the ages. https://t.co/nZK3g72JzD
# ------------------------------------------
# Tweet Text: I lost over 10% of my followers. I didn't have that many to begin with. What is going on.
# ------------------------------------------
# Tweet Text: Well... this is very good news for @we2_football.
# ------------------------------------------
# Tweet Text: As fuck
# ------------------------------------------
# Tweet Text: James gets the huge d and Tyler drops a hammer into the arms of his bud Marty. #godogs 11-11
# ------------------------------------------
# Tweet Text: @pavtalk @FacemojiHQ @danielsinger @pandastartup Should we make it?
# ------------------------------------------
# Tweet Text: #Goodnight 🌙 and #Godbless  🙏🏻 May your #dreams be amazing 😉 I am looking forward to a #beach day
# ------------------------------------------
# Tweet Text: temperature down 88°F -&gt; 86°F
# humidity down 13% -&gt; 11%
# wind 16mph -&gt; 17mph
# ------------------------------------------
# Tweet Text: #TheKing, who you got?
# ------------------------------------------
# Tweet Text: @chuckwoolery Stupid.
# ------------------------------------------
# Tweet Text: 8 steps to take before your CEO goes on camera
#  https://t.co/qVardeHoGT @PRDaily https://t.co/W5tqlWllPp
# ------------------------------------------
# Tweet Text: 19Oct1979 | 39yrs ago today @ Paisley Park https://t.co/QQh28iMQA4
# ------------------------------------------
# Tweet Text: Screenshot from https://t.co/92ALxwJxVV Bennigan begin again. Watt happens when the only weapons that fire are in t… https://t.co/rT3aXGprnE
# ------------------------------------------
# Tweet Text: Best pizza dough ever for me, I think, courtesy of @theperfectloaf ’s recipe. The toppings weren’t bad either 😀.
#
# T… https://t.co/yOVF1DmXBA
# ------------------------------------------
# Tweet Text: Who did it better?
# ------------------------------------------
# Tweet Text: We won... #GoZers
# ------------------------------------------
# Tweet Text: I haven’t been running much these past few month and needed to get motivated. I spent the evening at… https://t.co/i0IVXxIN7e
# ------------------------------------------
# Tweet Text: @Temple_VB WINS!!! 3-0 #TEMPLEvsMEMPHIS
# ------------------------------------------
# Tweet Text: wanna get my arm finished tonight 🤔
# ------------------------------------------
# Tweet Text: Aggies Landing
#
# @USUAggies
# #fallbreak #goaggies #aggiesalltheway #zionnationalpark @ Angels Landing https://t.co/A9YmDiGtZ9
# ------------------------------------------
# Tweet Text: I'm at El Burrito in Minneapolis, MN w/ @nouvelleblague https://t.co/ZqvAxPQZkR
# ------------------------------------------
# Tweet Text: Fuck Yesssss🖤😈😍🔫!
# officialkinkdotcom
# .
# .
# .
# .
# .
# .
#
# .
# .
# #menstyle #mensfitness #menshair #menswear #makemealite… https://t.co/wf9UpldkY6
# ------------------------------------------
# Tweet Text: OK we are up here bc we needed 4 seats and it was the only place there were 4 together, yet there are ROWS AND ROWS empty behind the bench
# ------------------------------------------
# Tweet Text: @BobTowey5 @CNBC Great stuff !!
# ------------------------------------------
# Tweet Text: Bout to just snack tonight. Aiden ate already
# ------------------------------------------
# Tweet Text: #thisisamerica #all that #glitters is #foolsgold
# @noma1910, thanks for hosting such a collection. @ New Orleans Mu… https://t.co/oDEscZf4wS
# ------------------------------------------
# Tweet Text: Y’all should take advantage of this
# ------------------------------------------
# Tweet Text: @Iam4thekidsRU He fuckin that pumpkin 🎃 up!
# ------------------------------------------
# Tweet Text: @Jojobersity Seriously though, congratulations!
# ------------------------------------------
# Tweet Text: @CarolynMc23 Yeah I know. Saw on the news so I decided to go. I waited 30 mins in line. The girl working was freaki… https://t.co/27Aih9bS7E
# ------------------------------------------
# Tweet Text: Our last band geek! Senior night for our Banana Bean. #colorguard #senioryear #family @ Sunrise Mountain High School https://t.co/Pos35YO5Du
# ------------------------------------------
# Tweet Text: @morris_ep @JamesTitcombe @AriadneLabs @RCObsGyn @EachBabyCounts Yes! Looking forward to working with and learning… https://t.co/9v5VLTfCgi
# ------------------------------------------
# Tweet Text: Enjoy the mothership children. I'm back in my element #fire https://t.co/eFwtx01cO3
# ------------------------------------------
# Tweet Text: @SorayaKirstin Big sis where is this at?
# ------------------------------------------
# Tweet Text: Reflection. | January, 2018 https://t.co/eMXRErJuji
# ------------------------------------------
# Tweet Text: I’m convinced you come to Ghana often but don’t live here
# ------------------------------------------
# Tweet Text: Do you remember when you joined Twitter? I do! #MyTwitterAnniversary https://t.co/4s6lFQBenl
# ------------------------------------------
# Tweet Text: @_queenkinsey what’s the link
# ------------------------------------------
# Tweet Text: Back to work tomorrow .... already thinking about the cocaine I have to do to get through this shift ...
# ------------------------------------------
# Tweet Text: Waukee recovers another fumble. This time at their own 30. 1&amp;10 Waukee. 9:46 2Q. #DragonEdge
# ------------------------------------------
# Tweet Text: @DJ_Biff_WPG Sure.  Will ask.
# ------------------------------------------
# Tweet Text: @wakatb @zoeinthecities @WildlifeTheFilm @scriptmag Thank you so much ☺️
# ------------------------------------------
# Tweet Text: If you’re from houston rt this .
# ------------------------------------------
# Tweet Text: Because their husbands are telling them what to think and do… Probably how  to vote too    😂😂🤣
# ------------------------------------------
# Tweet Text: Team Egypt at #techwomen18 wants to power their home country with solar power. Follow their work with… https://t.co/uu1eD0G61n
# ------------------------------------------
# Tweet Text: Home 🌙☕🌃 https://t.co/9hkhOlT39K
# ------------------------------------------
# Tweet Text: I’ve been madly in love with her forever now I wish I was famous and rich and good looking
# ------------------------------------------
# Tweet Text: This has spoken to me in a way that nothing else ever has
# ------------------------------------------
# Tweet Text: OH YES! Get your skin ready for the holidays! 😉💆🏻‍♂️💆🏻‍♀️💁🏻‍♀️
# Get pampered, revitalize and give your skin that hea… https://t.co/M7juJCkFO0
# ------------------------------------------
# Tweet Text: .
# spent the night
# in a run down old cemetery
# a dead man’s party
# they played the movie
# Night of the Living Dead… https://t.co/HTTjsR3czA
# ------------------------------------------
# Tweet Text: @LastManStanding This is great. Vanessa won’t validate their alibi!! Vanessa pranking Mike!! Great  show!!😂😂🤣😅
# ------------------------------------------
# Tweet Text: @DennisDMZ Lol. Too funny Dennis
# ------------------------------------------
# Tweet Text: Washed Friday’s
# ------------------------------------------
# Tweet Text: @coasterstudios Be sure you check out @KarlTheFog - he’s big out in the Bay.
# ------------------------------------------
# Tweet Text: If a girl covers my face with an emoji or sticker in a picture ima dub her &amp; assume she for the team
# ------------------------------------------
# Tweet Text: I don’t know how to behave when there’s an open bar https://t.co/Y994AVYdus
# ------------------------------------------
# Tweet Text: @Angelamarytayl1 @Christo09278206 @Chrispr77792659 @JoinerMargie @TonyKimble4 @ACNamlik @MarilynLavala… https://t.co/w7qs5ssXW7
# ------------------------------------------
# Tweet Text: @SteveTannuzzo @SadieHartmann @SGJ72 I had a paperback and found a sweet brand new hardcover in a used shop. 😍
# ------------------------------------------
# Tweet Text: Lucid Dreams https://t.co/UH418M7aqu
# ------------------------------------------
# Tweet Text: @KatyTurNBC It's October, so hubby might be right.
# ------------------------------------------
# Tweet Text: END OF FIRST QUARTER: @StaleyFootball 7, Liberty 0 @N2SportsStaley @810varsity @StaleyNews @PrepsKC @KcPrepReport @jwestMSHSAA @scorestream
# ------------------------------------------
# Tweet Text: @NataliaSports and @DilleyISD take the field https://t.co/wgd3MfreqU
# ------------------------------------------
# Tweet Text: great win boys im so proud of you guys ⚾️💪
# ------------------------------------------
# Tweet Text: you got a beautiful face but got nothing to say. oh
# ------------------------------------------
# Tweet Text: Scientology &gt;&gt;&gt;
# ------------------------------------------
# Tweet Text: Did you ever go to sleep with Bo Derrick, and wake up with Bo Diddley?
# ------------------------------------------
# Tweet Text: That’s quiet Jerry from reservations! Flexing his vocals in a disco ball Monty python get up https://t.co/iHU9NTt3Ic
# ------------------------------------------
# Tweet Text: y’all what me to tell y’all bout the time my boyfriend almost ran over me in my car?😂😂😂😂😂😂😂😂
# ------------------------------------------
# Tweet Text: Canes capitalize on the turnover. Byron bowls his way into the endzone from 17 yards out. @MonroeCanesFB 28, @JeffersonFootba 7 - 0:59 2nd.
# ------------------------------------------
# Tweet Text: @BPPub nice crowded Tonite. Very dog friendly and relatively quiet; it's still early.
# ------------------------------------------
# Tweet Text: @realnrnb I finished today. It was so goood.
# ------------------------------------------
# Tweet Text: Pecos punted and then Sweetwater fumbles. Gary Salcido recovers for Pecos. Eagles are driving from the 50-yard line.
# ------------------------------------------
# Tweet Text: DeAndra just said she eat gold fish like crack heads eat crack. Direct quote. 😑 I hate this bitch so bad. I quit being friends.
# ------------------------------------------
# Tweet Text: finally ordered a beto shirt am so excited
# ------------------------------------------
# Tweet Text: I just had a huge fight with my parents and I kind of want to go die
# ------------------------------------------
# Tweet Text: Or two*
# ------------------------------------------
# Tweet Text: subtle flexes &gt; doing the most, making it known that you're not used to having .
# ------------------------------------------
# Tweet Text: What an amazing day spent shooting with @lionbabe &amp; this fabulous crew! 👗: @jeffhova &amp; 💇🏼‍♀️: @KyssCoiffeuse &amp; 💄… https://t.co/MB85QhEpMf
# ------------------------------------------
# Tweet Text: old school lime https://t.co/xkODfaanMD
# ------------------------------------------
# Tweet Text: Jemele Hill Calls Police Shootings of Unarmed Black Men 'State-Sanctioned Killings' https://t.co/LwVS7G4E13 via @BreitbartNews
# ------------------------------------------
# Tweet Text: The Saudis need a month, so Trump can get through the midterms; then, he can give MBS the cover he needs without po… https://t.co/6xnivO6K90
# ------------------------------------------
# Tweet Text: Oh I’m DRUNK drunk
# ------------------------------------------
# Tweet Text: Come join us for dinner, Open 5 pm  to 10:30 pm. #anikis #anikissushi #bestoffremont2013 #sushitime #sushi #fremont… https://t.co/4sfv2QxnPA
# ------------------------------------------
# Tweet Text: @JacketPotato97 @sajidjavid He didn't mention race or he would have mentioned men of Pakistani origin, by saying As… https://t.co/8BaiA8dMUx
# ------------------------------------------
# Tweet Text: Fuck Cardenas till death.
# ------------------------------------------
# Tweet Text: what should I eat for din din
# ------------------------------------------
# Tweet Text: @Campster I keep asking why anyone would name it that way and it had to be in the hopes for accidental cross-traffic
# ------------------------------------------
# Tweet Text: Upstate tomorrow morning 💨
# ------------------------------------------
# Tweet Text: @Potomacbeat @ThomONeil1 @catmonkey22 Everytime you get a blood test. Or taking bp. Or getting a tb test.
#
# Pee te… https://t.co/P1zHIPHAR7
# ------------------------------------------
# Tweet Text: @B2B_DMPS can’t believe I missed you guys on campus today #RedRising
# ------------------------------------------
# Tweet Text: @tylerwg88 Oh buddy.
# ------------------------------------------
# Tweet Text: mood. https://t.co/GWlsP7bRJg
# ------------------------------------------
# Tweet Text: @FRCAction you people are pigs. Your men, women and children are nothing but trash
# ------------------------------------------
# Tweet Text: Twitter for my antique/novelty/kitsch art shop. On vacation for a little while. I've been way too bizzy living life… https://t.co/05inBczvUW
# ------------------------------------------
# Tweet Text: Lot of amateur orthopedists diagnosing @TreBall21
# ------------------------------------------
# Tweet Text: @SHSRaiderFB 36
# South Spencer 0
# 2nd
# #tgd
# ------------------------------------------
# Tweet Text: A long Harrison drive stalls in the red zone, but they still knock through a field goal to go up 10-0 on Alma at the end of 1Q #5NEWSFFN
# ------------------------------------------
# Tweet Text: Twas a Stormy #Disney Dream day. #PortCanaveral #Florida #weather #clouds @ Port Canaveral https://t.co/kqNX9kPrJu
# ------------------------------------------
# Tweet Text: One burnt the shit outta you and one shocked the shit outta you.
# ------------------------------------------
# Tweet Text: #MakingaMuderer2 do you think this guy even knows what a heartbeat is? IMO he just got school KZ style https://t.co/c0dgqLROdN
# ------------------------------------------
# Tweet Text: @treasonstickers McConnell
# ------------------------------------------
# Tweet Text: Almost home.... (@ William P @HobbyAirport in Houston, TX) https://t.co/4T5u7Q6rj9
# ------------------------------------------
# Tweet Text: Welcome to the sisterhood @CCchanginglives #sisterhoodnight #church #fellowship even happier our night will support… https://t.co/m4wr9UJ1Oe
# ------------------------------------------
# Tweet Text: All the time!!!
# ------------------------------------------
# Tweet Text: lmao i guess just a break from fb. ion have nothing to do 😩
# ------------------------------------------
# Tweet Text: @mogster @amysmith292 @sampay The writer is Brian Michael Bendis he created Jessica Jones and the star of the new animated Spider-Man movie
# ------------------------------------------
# Tweet Text: 1970 Columbia Minerva Afghans Leaflet No. 2522 Knit Crochet Book.
# Groovy mid century pattern book in near perfect… https://t.co/BKv5ANvI5r
# ------------------------------------------
# Tweet Text: @Thereal_bellis @WalkerStarr1 Read your tweet again and you should know what I’m betting retarded fella.
# ------------------------------------------
# Tweet Text: Hey Thornton, Colorado, our meads are now available at Total Beverage! We’re also tasting our meads at Daveco Beer,… https://t.co/NgElfTf69R
# ------------------------------------------
# Tweet Text: Chillin on a Friday night way with my pup! @ Bristow, Virginia https://t.co/rgqlKD47Lc
# ------------------------------------------
# Tweet Text: Imma find me a caramel shawty on here one day
# ------------------------------------------
# Tweet Text: @bombmerica crazy part is she was always tweetin about females showin ass n titties on Twitter LMAO
# ------------------------------------------
# Tweet Text: Ain’t no question if I want it, I need it
# ------------------------------------------
# Tweet Text: We drew a wall! Stop by, take a pic and tag us. Use #cakeboxfallwall 🍁🍁🎃 @ Swoon at The Cake Box https://t.co/oXBYrBv4EL
# ------------------------------------------
# Tweet Text: @goalieguy87 @Lakeside_Spdwy @WorldofOutlaws Nice sunset!
# ------------------------------------------
# Tweet Text: @nativirod @DavidBegnaud @CBSEveningNews Because Florida is red state and they don't enforc codes.
# ------------------------------------------
# Tweet Text: @Vikings @LataviusM Case also doesn't have Kevin and other phenomenal coaching staff around him just as he didn't b… https://t.co/cxy0hTQvPG
# ------------------------------------------
# Tweet Text: @dakota_skyexxx You can start by refunding my 200 for a bs custom!!
# ------------------------------------------
# Tweet Text: Yes sir ..  a leaf 🍂
# ------------------------------------------
# Tweet Text: The states that consistently rank in the bottom of the fiscal solvency rankings are those where state officials hav… https://t.co/65NTdwmW1f
# ------------------------------------------
# Tweet Text: @MikeCardano they were in macau during WC . taking bets from HIGH ROLLERS lol. they went to vegas too . got busted… https://t.co/gfrqRajrFJ
# ------------------------------------------
# Tweet Text: Yh so this crazy thing happened today.. my mom couldn’t see the road with such heavy rainfall and she decided to pu… https://t.co/FQRbfO05MD
# ------------------------------------------
# Tweet Text: Texas Chainsaw Massacre 🎃⛓👻💀
# ------------------------------------------
# Tweet Text: Just posted a photo @ Raxual -India Nepal Border https://t.co/DGOLC7BSd4
# ------------------------------------------
# Tweet Text: Democrats Believe High Hispanic Turnout Will Turn Arizona Blue https://t.co/vI8Pq8K55F via @politicususa
# ------------------------------------------
# Tweet Text: Make no mistake, this is an Invasion. Lock and Load
# ------------------------------------------
# Tweet Text: Tomorrow is the day ‼️ and you better  #bELieve⚔️🛡
# ------------------------------------------
# Tweet Text: @michymilli never
# ------------------------------------------
# Tweet Text: You ever tell people straight up that you’re about to play them and then they still get mad when they get played?
# ------------------------------------------
# Tweet Text: @gcxsh Already 😎
# ------------------------------------------
# Tweet Text: @ThisShitRunDeep My gramma had 2 her mom had like 12 or 13 tho
# ------------------------------------------
# Tweet Text: i just got so much shampoo in my eyes 😭 but sunday i’ll be back in action 💁🏽‍♀️💁🏽‍♀️💁🏽‍♀️
# ------------------------------------------
# Tweet Text: no more thinking bout what you do there’s no more me running back to you #unfoolish
# ------------------------------------------
# Tweet Text: @seanhannity The literal insanity, the psychological disorders… I think much of the Democrat Party agenda has deriv… https://t.co/RvoQLymcHd
# ------------------------------------------
# Tweet Text: hahaha I’m funny when I’m sad
# ------------------------------------------
# Tweet Text: LET'S GO #DODGERS STAY FOCUSED AND GET THIS W!!! ALMOST THERE......... PLEASE!!!! #NLCS https://t.co/BlmNchVCF7
# ------------------------------------------
# Tweet Text: She’s tight that nobody will pay her for her services cuz they know they’ll get it free 🤣
# ------------------------------------------
# Tweet Text: Need support and resources for bringing digital learning into your school/district? We have an opportunity for you… https://t.co/XLQeGYW7Vp
# ------------------------------------------
# Tweet Text: @OutlawCountry6 That's extortion
# ------------------------------------------
# Tweet Text: Payton got pretty much whatever it wanted on its first drive. Cortez Savage caps it off with a one yard TD run. Gri… https://t.co/JsSrggSFBA
# ------------------------------------------
# Tweet Text: Been running pretty awful forever in the lottery, but have a feeling tonight is my night! Letsssss gooooo
# ------------------------------------------
# Tweet Text: Me with anyone 😂
# ------------------------------------------
# Tweet Text: I feel the imposter syndrome from a class perspective sometimes, though I can’t even fathom what it would feel like… https://t.co/3T5JJBR7hF
# ------------------------------------------
# Tweet Text: Desert Rose 🌵🥀 Got my hair touched up. Tested &amp; cleared. ✅
# Available for scenes or trade content, also photo/video… https://t.co/3LEReQRCTa
# ------------------------------------------
# Tweet Text: @TezHunchos I’m home rn we on fall break
# ------------------------------------------
# Tweet Text: Colombo: 5:57am: sunrise
# sunset will be at 5:53pm
# ------------------------------------------
# Tweet Text: I cast my Heisman ballot for #WillGrier! Click the player you think deserves the Heisman House vote. (📍@NissanUSA)
# ------------------------------------------
# Tweet Text: If she keeps up the same level of consistency then why not. She deserves as much energy. One brought me to the worl… https://t.co/vba83BBf1y
# ------------------------------------------
# Tweet Text: https://t.co/st3xIh61TZ
#
# Y’all. Go listen to this whole mf album
# ------------------------------------------
# Tweet Text: 17 yd TD pass from Staerkel to Wnek. Kimberly 14, @ChiHi_football 0. Listen on 103.1FM and https://t.co/O5tYV4a3gl.
# #ecscores #wiaafb #wisfb
# ------------------------------------------
# Tweet Text: That’s the end of the first half. Your @NAFO_Falcons_FB lead the @RHHSBearcatsFB 14-10. #NaFoYouKnow
# ------------------------------------------
# Tweet Text: @marie_murra Your not fighting alone...
# ------------------------------------------
# Tweet Text: Predictions? I want a game 7, both teams are pretty evenly matched.
# ------------------------------------------
# Tweet Text: 🥚🍳🥞🥓🥩🧀🍞🥐 😋
# #breakfast #vegas #sunset #nevada @ Egg Works https://t.co/uRqmTOKQXl
# ------------------------------------------
# Tweet Text: Let me see if I get this straight.... @lancearmstrong can’t have credit for a championship because of steroids,  a… https://t.co/2ic8ICbMEc
# ------------------------------------------
# Tweet Text: #fbf 2015 Homecoming. The best homecoming tailgate goes down next Saturday in the #ATL. #spelhousehomecoming… https://t.co/4ecUTb7UOH
# ------------------------------------------
# Tweet Text: Date line Hancock Maryland !.The police Chief of Hancock Maryland has resigned .The police here protect the violato… https://t.co/o31E8KtfBe
# ------------------------------------------
# Tweet Text: Wedding party photo - Houston photographer
# .
# .
# .
# .
# .
# .
# #HoustonPhotographer #HoustonWeddingPhotographer… https://t.co/vZJFNST6ey
# ------------------------------------------
# Tweet Text: #Olitz 💕 nightly edition https://t.co/7rHRybpvyb
# ------------------------------------------
# Tweet Text: Got my lotto tickets!
# ------------------------------------------
# Tweet Text: but fuck shaye right??
# ------------------------------------------
# Tweet Text: @rmcoop757 That’s right! Let’s hangout soon. Also how was work
# ------------------------------------------
# Tweet Text: when i tell u i hate texting.. i just send a shit load of audio messages
# ------------------------------------------
# Tweet Text: So close to deleting him off everything
# ------------------------------------------
# Tweet Text: Since when does fucking Kanter get superstar calls???? Fuck that. #nets
# ------------------------------------------
# Tweet Text: Me and Mary just tried to stop the ice cream truck and that was a complete FAIL! 😂
# ------------------------------------------
# Tweet Text: I'm at @SalonTropics_br in Baton Rouge, LA https://t.co/mpxILZGa3m
# ------------------------------------------
# Tweet Text: @EmperorCoolidge @CNBC @CNBCMakeIt I’d place 50% in trust, give away 40%, give 5% to family and close friends, 5% for me
# ------------------------------------------
# Tweet Text: @CaliGamer @GeorgeTakei Republicans current hate mobs.Democrats work and create meaningful jobs.I’m not the 1% or e… https://t.co/tAXPuz1513
# ------------------------------------------
# Tweet Text: i would have no problem beating the fuck out of that girl after seeing this 🤷🏻‍♂️
# ------------------------------------------
# Tweet Text: End of 1Q: @LafayetteHigh leads Lagrange 14-0.
# ------------------------------------------
# Tweet Text: Fraternal organization? Seriously @nytimes that is an F. Please look up def....violent white nationalist is not eve… https://t.co/RAruix8K4e
# ------------------------------------------
# Tweet Text: @pa00lla I love you too!❤️
# ------------------------------------------
# Tweet Text: Wwwaaaasssssss uuppp with it gurl
# ------------------------------------------
# Tweet Text: Hi twitter just your daily reminder that @maadisoncarley is a gift from The Good Place and I will cherish her and love her forever
# ------------------------------------------
# Tweet Text: It has been an apple kind of day! Rewards being reaped. Stomachaches be damned! #applecrisp #steppappleorchard… https://t.co/fh045w9rAw
# ------------------------------------------
# Tweet Text: And does a great job at it. 😎
# ------------------------------------------
# Tweet Text: One good prank deserves another. Hahaha. #LastManStanding
# ------------------------------------------
# Tweet Text: I've had it with these fake Christian hypocrites using the Bible and the words if my saviour to support one of the… https://t.co/yUE4p5RLfv
# ------------------------------------------
# Tweet Text: Hey @MichelleObama, he is talking about your best friend; your partner in crime. How could anyone have any respect… https://t.co/nC8TPIDh1r
# ------------------------------------------
# Tweet Text: MAKE THIS HAPPEN!
# ------------------------------------------
# Tweet Text: End of the 1st here in Sulphur. Acadiana leads 8-0. Rams with the ball following a Morgan Clark interception. #SWLAPreps
# ------------------------------------------
# Tweet Text: im so loyal I watch porn with no girls in it
# ------------------------------------------
# Tweet Text: @Bornabrit1 Are you misinterpreting what I? Post?
# ------------------------------------------
# Tweet Text: https://t.co/6DHJ7S0zc0 #EBOBeardButter  #EBOBeardwash #EBOBeardButter &amp; #EBOBeardwash Order ANY 8oz size jar and g… https://t.co/4hd9cYvqTS
# ------------------------------------------
# Tweet Text: https://t.co/x10E6xSZAr Archive
# Putin also claimed America holds “some responsibility” for the disappearance of Was… https://t.co/wZR2ilIhFl
# ------------------------------------------
# Tweet Text: My momsss called me with great news I swear I’m sooo happy I’m crying.. she deserves all the blessing in this world… https://t.co/7calqzMYPg
# ------------------------------------------
# Tweet Text: @longsnapper53 @washingtonpost The level of intelligence in ur tweets suggest ur claim to an Ivy League education i… https://t.co/3frIuK8wA1
# ------------------------------------------
# Tweet Text: @laaaayne @bigg_sexxxy_j The chapstick companies rackin in money like: https://t.co/If00S3O6EF
# ------------------------------------------
# Tweet Text: Aw, Miss you Bingo &amp; Davey! 💜 @MojaveLords @ranchodelaluna @Rancho_Mezcal https://t.co/fbK2qkJJuY
# ------------------------------------------
# Tweet Text: Nope! Didn’t turn it on last winter— not doin it this winter! #woodburningstove @ Ambler, Pennsylvania https://t.co/8qlcDTRqKF
# ------------------------------------------
# Tweet Text: @KC_Fanatic95 @StephenSerda Point to you...
# ------------------------------------------
# Tweet Text: The Sons of Liberty of 1760s-70s Boston might disagree with you. #mobbing
# ------------------------------------------
# Tweet Text: @PalmerReport He could still be playing for a Pardon.
# ------------------------------------------
# Tweet Text: I’m over here talking to my coworker about head with ice and she’s like “me and my bf always use ice”
# I’m convince… https://t.co/8dS659r7aS
# ------------------------------------------
# Tweet Text: @all3points @eBay Someday I'll find one. Hopefully.
# ------------------------------------------
# Tweet Text: Watching my life fall apart but I know I can but won’t  do something about it is like ordering a burrito and forget… https://t.co/cuPxXd4Xf4
# ------------------------------------------
# Tweet Text: I’m so damn hungry 🙄🙄
# ------------------------------------------
# Tweet Text: Time to go buy a lottery ticket
# ------------------------------------------
# Tweet Text: @Acosta Dear Diary
# ------------------------------------------
# Tweet Text: @AwkwardlyReeRee My ReeRee 😊😘
# ------------------------------------------
# Tweet Text: @Grover1James AP is the last of a dying breed man lol
# ------------------------------------------
# Tweet Text: Is y’all Cash Apps acting weird too?
# ------------------------------------------
# Tweet Text: Okay it’s a whole VIBE 💕
# ------------------------------------------
# Tweet Text: @Abarbbbbb Chewing on beat and shit huh? 😂
# ------------------------------------------
# Tweet Text: @SaraCarterDC He should most certainly be held at the same standards as everyone else!!!! Why should there be any o… https://t.co/l84KSOKNFD
# ------------------------------------------
# Tweet Text: About to watch #HTGAWM
# ------------------------------------------
# Tweet Text: THIS SONG STILL SLAPS!!!!
# ------------------------------------------
# Tweet Text: @howjrodseesit @johniadarola @Snowden Idiot! @Potus @BarackObama #BlueTsunami #TheBossisBack! @LeahVukmir… https://t.co/3e7VP7lOsG
# ------------------------------------------
# Tweet Text: I feel myself getting sick 😭
# ------------------------------------------
# Tweet Text: Monterey in all-Columbia blue tonight with white numbers. Coronado in white jerseys and helmets, red pants, hard-to… https://t.co/CezAnwOJIi
# ------------------------------------------
# Tweet Text: Pretty excited to finally see @TheRealXPac in action! https://t.co/tlQUxGLwvb
# ------------------------------------------
# Tweet Text: @SocialPowerOne1 @Americansoaring Never watch milk toast CNN.
# ------------------------------------------
# Tweet Text: @realMatMolina Obama almost doubled total deficit from 10.6 trillion to $19.9 trillion. He’s the champ so far.
# ------------------------------------------
# Tweet Text: Gym time! @ 24 Hour Fitness - San Juan Capistrano, CA https://t.co/o8CcB6YPTn
# ------------------------------------------
# Tweet Text: It is amazing how the @ghsfalconflock @falconsac_2727 and @glendale_cheer came together to support @myharmonyhouse… https://t.co/eX7yI2R4QH
# ------------------------------------------
# Tweet Text: Falcons trail the Highlanders 14-8 entering the fourth qr @ West Milford High School https://t.co/3Q67Ig5wEn
# ------------------------------------------
# Tweet Text: In the name of the bookies.... amen🙏🏾
# ------------------------------------------
# Tweet Text: @DanRather RINGER
# ------------------------------------------
# Tweet Text: @laoluprof You wey know😂
# ------------------------------------------
# Tweet Text: @OrlandoUnicorn Good times, may they return soon !
# ------------------------------------------
# Tweet Text: PD is the MVP: he ordered Chinese takeout for dinner. And then sushi for a mid night snack 🙌🏽
# ------------------------------------------
# Tweet Text: First time the #Brewers have not worn blue all playoffs
# ------------------------------------------
# Tweet Text: So @gordonhayward has the best hair in the game
# ------------------------------------------
# Tweet Text: .I had put a reminder about this event, but forgot that I'll be in Washington DC from the 24th Oct. What a bummer!
# ------------------------------------------
# Tweet Text: Only in la would the barista be high af dropping shit moving as slow as possible 😂
# ------------------------------------------
# Tweet Text: MONROE AREA 28, JEFFERSON 7, 17-yard run by Byron, Ferguson kick. 0:59 left in the 2nd quarter. #wdun
# ------------------------------------------
# Tweet Text: @ballroombeauty7 Naughty!! X
# ------------------------------------------
# Tweet Text: Congrats to our Senior Marching Longhorns! https://t.co/YU1WFzf1Kh
# ------------------------------------------
# Tweet Text: Y? @ Hot100Columbus https://t.co/MKbMkzAj4e
# ------------------------------------------
# Tweet Text: I’m dying my hair nest Saturday. Just a PSA
# ------------------------------------------
# Tweet Text: Bonny Eagle has hing tough and gets ball to start the second half down 28-21
# #VarsityMaine
# ------------------------------------------
# Tweet Text: @darealestdess too late
# ------------------------------------------
# Tweet Text: Gods always got my back
# ------------------------------------------
# Tweet Text: my brother and dad are having their time of their life in HHN 😂 while my mom and I are having a girls night.
# ------------------------------------------
# Tweet Text: @Zubee_P @Chicago Holy Google translate
# ------------------------------------------
# Tweet Text: Goonies is a classic I can never turn down watching
# ------------------------------------------
# Tweet Text: @Jimbilmer I don't know anyone who went broke from spending too much on fertilizer.
# ------------------------------------------
# Tweet Text: Day 18 done! #dddrawtober “Design your own sugar skull” + “bottle” #inktober. Went with traditional Aztec designs f… https://t.co/XBpnF1WlxV
# ------------------------------------------
# Tweet Text: Steak and fried whole Maine lobster @rivolis https://t.co/3cZu0wRljx
# ------------------------------------------
# Tweet Text: Being in the sky, does it ever get lonely?
# ------------------------------------------
# Tweet Text: @realDonaldTrump You like playing with words...so do I.....T.R.U.M.P.=Terrifying Republican Useless Manipulative Prick!!!!!!!!!!!
# ------------------------------------------
# Tweet Text: Agreed! Good luck Wildcats!
# ------------------------------------------
# Tweet Text: Their house got egged!;#FreshOffTheBoat
# ------------------------------------------
# Tweet Text: October in the West Village is where it’s at ✨♥️🍂🎃 (Strategically cropped out a ghost and a ghoul hanging out of th… https://t.co/CfTXb54N92
# ------------------------------------------
# Tweet Text: @GBankrolls It’s entertaining
# ------------------------------------------
# Tweet Text: this definitely is it...now go wash the cancer off
# ------------------------------------------
# Tweet Text: #nomnom #voodoodoughnuts #denver #richardpryor #redfoxx @ Voodoo Doughnut https://t.co/zvSiJVWwmU
# ------------------------------------------
# Tweet Text: @RealSaavedra I recommend McMullin hook up with Flake and Sasse.  We would then have Mo, Curly &amp; Larry.
# ------------------------------------------
# ...
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694a8c8>)
# Tweet Text: @Truth2Pwer @MalcolmNance This a cult....where is @congress?
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705808>)
# Tweet Text: @MegaMilkshakes It should be. Are you in the US or Canada. It could depend on where you live.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705a08>)
# Tweet Text: We stopped at Michael's to get all the necessary supplies to make our pumpkin creation.
# #SBESLobbyPumpkinPatch… https://t.co/zSFq9kvmAX
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d7748>)
# Tweet Text: @CalzadaPete @majmokokusa @charliekirk11 Show me one election where illegals didn't vote. Just one....
#
# I'll also wait
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959588>)
# Tweet Text: I read the caption in his voice
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84769591c8>)
# Tweet Text: Minor touchdown with 11:14 left in the 2nd. Minor 13 Chelsea 3.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962cc8>)
# Tweet Text: His what y’all do ? @paradisekayy
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956d08>)
# Tweet Text: I come home from work to go to sleep to wake up for work... what a life
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c548>)
# Tweet Text: People don’t be genuine
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694a8c8>)
# Tweet Text: #TheKing, who you got?
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705908>)
# Tweet Text: Big start for the Trojans.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c6c8>)
# Tweet Text: @4FreeEBooks Perhaps free copies ought to be sent to Donald Trump &amp; his ilk plus to all the Prime Ministers &amp; Presi… https://t.co/I3jTo0vqmV
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c648>)
# Tweet Text: That ends @LastManStanding #LastManStanding
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959a88>)
# Tweet Text: this is so true omg
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d7cc8>)
# Tweet Text: Mrs Engel dm’d me on insta telling me to go vote😂👍🏼 already ahead of ya girly
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962c48>)
# Tweet Text: Minor set back for a big come up
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c608>)
# Tweet Text: Let me share common sense with liberals:
# You can't accept millions of "refugees" from war torn countries because it… https://t.co/4XRbSsDfGX
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959548>)
# Tweet Text: @hilory @CoryDHutch @RickPetree @BillKristol @CarsonDunn10 There's always a ton more we don't know about with those idiots.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705a88>)
# Tweet Text: Sorry Ava took my phone @kaleygracee
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705508>)
# Tweet Text: @lyssquire Hit him with a "s-con"
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c6c8>)
# Tweet Text: @ProudResister Trump speeches at his rallies trump actions around the world supporting murdering dictator.shows tru… https://t.co/eTVsQnpjpE
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c608>)
# Tweet Text: drizzle -&gt; light intensity drizzle
# temperature down 52°F -&gt; 49°F
# humidity up 76% -&gt; 81%
# wind 11mph -&gt; 16mph
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959608>)
# Tweet Text: @xavicastrobcn Landed now
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959588>)
# Tweet Text: @ForOurFutureWI @kharyp Trump ass kissers  aka gop
# Playbook
#
# 1.LIE
# 2.FEAR
# 3.RIG
#
# VOTESMART
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962648>)
# Tweet Text: @marinemom34 4: 00 min left 1rst  tied at 14
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c548>)
# Tweet Text: No. 1: Hold on to the $$$!
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959088>)
# Tweet Text: @n00rvana I already follow b🌞 I will most definitely be on the look for your next orders 🦋 your craft is amazing!
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962648>)
# Tweet Text: @Phish_FTR What in tarnation
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705908>)
# Tweet Text: Sheeessshhhhh @JuiceWorlddd @1future ... reallly outdid yourselves this time 🤤🙏🏽
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d7308>)
# Tweet Text: Got tickets for Marc Anthony 😩
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959308>)
# Tweet Text: @og_kris14 LMFAO bro i have him as a Pandora startion nigga is funny as fuck
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956f08>)
# Tweet Text: I don’t have one night stands I have one hit wonders
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956c48>)
# Tweet Text: Being in Tennessee surrounded by Tennessee fans wearing Alabama gear is the greatest feeling I’ve felt in a long time 🐘🐘🐘 #RollTide
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705708>)
# Tweet Text: Good Night, I miss you. #Seeu in My Dreams.🙏😘
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d73c8>)
# Tweet Text: We are live here at Tulsa Oktoberfest at the Riverwest Festival Park and we’re ready to party!! We’re giving away t… https://t.co/vnGAEOGaEW
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959c88>)
# Tweet Text: This is the rough draft of my don’t interrupt poster it will prettier soon . My kids have tried to convince me thei… https://t.co/MtWGk1Npgr
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959548>)
# Tweet Text: @JunkoPoole @ScuderiaFerrari The penalty is fair, it was a red flag and he didnt brake the car until 27s son... he deserves the penalty
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c6c8>)
# Tweet Text: @collegeswimnews @coach_bowman @ASUSwimDive Forks up!
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d7088>)
# Tweet Text: @vickysanderson @Mikeggibbs @MacLeodLisa @WomenON @janet_humserv @AmyFeePC @KarahaliosPC It’s pretty despicable.  I keep saying this lately.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956c48>)
# Tweet Text: @TonkaSly @OrdyPackard Everyone wants the exotic QSL card.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959c88>)
# Tweet Text: Every just buy tickets for 6 shows in one sitting?
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959548>)
# Tweet Text: Definitely worth reading and noting.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962cc8>)
# Tweet Text: End of 1st quarter Opelika 24 Stanhope Elmore 0 https://t.co/Q7vj492dCR
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d7048>)
# Tweet Text: @PressSec Here is what we’re stuck with until Jan 21 2019 https://t.co/Vpg1vn3XTw
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959048>)
# Tweet Text: Happy Birthday @_hayyrayy19 ! Hope today is full of fun and love!!!😘 https://t.co/L7XFUv6ULd
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694ca48>)
# Tweet Text: @Geztour @Daward79 @DonaldJTrumpJr I don’t care if it’s black and white striped or orange SHE NEEDS TO ROT IN PRISON!!!!!!!!!
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694c608>)
# Tweet Text: I got 5 shipment notification emails today..... 😳 lets hope I get home before Brandon EVERY day next week #Whoooops
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962cc8>)
# Tweet Text: We both grown so how we feel we can let it show
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956c48>)
# Tweet Text: Downtime.  Swan Lake the Joffrey @ Auditorium Theatre https://t.co/R70wGawuPT
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705748>)
# Tweet Text: Damn hurtful 💔... your still cute 😂 lol
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705b48>)
# Tweet Text: who’s awake?
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d73c8>)
# Tweet Text: These people are nowhere near the Us/Mexico border! How is this scary! I just ate dinner and I’m laying in bed! I’m not scared at all! #cnn
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962988>)
# Tweet Text: @KaylieRuderman I’m gonna cry myself to sleep everyday and then sob when you get here.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956f08>)
# Tweet Text: not gonna be anywhere near mississippi for 3 days and im so excited 🤪
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956d88>)
# Tweet Text: Kinders actively engaging in the Tea Party chat and sharing their letter T word in Spanish to classmates.… https://t.co/hIs0uonKCZ
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d72c8>)
# Tweet Text: People are so rude. Dude came in with boots and tracked mud everywhere. Had his feet up on the machine the whole ti… https://t.co/YdjBxj5783
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f84766d73c8>)
# Tweet Text: @MattWalshBlog Dinosaurs were on the Ark. They got off like all the others once Flood ended. But the Earth was no l… https://t.co/uB8lw3hSg8
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476962cc8>)
# Tweet Text: End of the first quarter @NACardinals leads @BraymerBobcats 24-0
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f847694a8c8>)
# Tweet Text: Mount Vernon
#            Fall Harvest
#         and Family Days
#           October 20, 21
#   #GeorgeWashington… https://t.co/33wnYISetZ
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476956d88>)
# Tweet Text: Disabled vehicle has cleared. in #Austin on Farm-To-Market Rd 812 WB at TX 130 #ATXtraffic https://t.co/8laei8iLor
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476959348>)
# Tweet Text: #Repost @neowomanism
# ・・・
# We gotta sprint to the polls on November 6th. @ Maryland Hall for the Creative Arts https://t.co/YDWAvYkqRb
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705fc8>)
# Tweet Text: @DanRather This is yet another example of his true character. I will never understand the undying devotion heaped upon him.
# ------------------------------------------
# Raise an Error:
# (<class 'BrokenPipeError'>, BrokenPipeError(32, 'Broken pipe'), <traceback object at 0x7f8476705808>)

# %%
ckey="iTrUDoKffZNLfSYvc9ctDXGJZ"
csecret="XEuXkw8AesuyxYaiPG7CSI1r0IhuXhcN8vvTYyimrCoAvMShU4"
atoken="1048005627816169473-5tJdLYafXOfCUaHWDFtcqjCvBRdU90"
asecret="iIQRVbZTN625Zn1xRPwDKkOH8Mk4xqrAEn8ICb39CTIeY"

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
class TweetsListener(StreamListener):
 
    def __init__(self, csocket):
        self.client_socket = csocket
 
    def on_data(self, data):
        try:
            print(data.split('\n'))
            self.client_socket.send(data)
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True




def sendData(c_socket):
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    twitter_stream = Stream(auth, TweetsListener(c_socket))
    twitter_stream.filter(track=['trump'])
    
    

s = socket.socket()     # Create a socket object
host = "127.0.0.1"      # Get local machine name
port = 5555      # Reserve a port for your service.
s.bind((host, port))    # Bind to the port

print("Listening on port: %s" % str(port))

s.listen(5)                 # Now wait for client connection.
c, addr = s.accept()        # Establish connection with client.

print( "Received request from: " + str( addr ) )

sendData( c )
