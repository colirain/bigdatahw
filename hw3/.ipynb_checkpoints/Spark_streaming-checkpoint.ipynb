# %%
from pyspark import SparkConf,SparkContext
from pyspark.streaming import StreamingContext
from pyspark.sql import Row,SQLContext
import sys
import requests
# create spark configuration
conf = SparkConf()
conf.setMaster('local[2]')
conf.setAppName("TwitterStreamApp")
# create spark context with the above configuration
sc = SparkContext(conf=conf)
sc.setLogLevel("ERROR")
# create the Streaming Context from the above spark context with interval size 2 seconds
ssc = StreamingContext(sc, 60)
# setting a checkpoint to allow RDD recovery
ssc.checkpoint("checkpoint_TwitterApp")

# %%
def aggregate_tags_count(new_values, total_sum):
    return sum(new_values) + (total_sum or 0)

def get_sql_context_instance(spark_context):
    if ('sqlContextSingletonInstance' not in globals()):
        globals()['sqlContextSingletonInstance'] = SQLContext(spark_context)
    return globals()['sqlContextSingletonInstance']

def process_rdd(time, rdd):
    print("----------- %s -----------" % str(time))
    try:
        # Get spark sql singleton context from the current context
        sql_context = get_sql_context_instance(rdd.context)
        # convert the RDD to Row RDD
        row_rdd = rdd.map(lambda w: Row(hashtag=w[0], hashtag_count=w[1]))
        # create a DF from the Row RDD
        hashtags_df = sql_context.createDataFrame(row_rdd)
        # Register the dataframe as table
        hashtags_df.registerTempTable("hashtags")
        # get the top 10 hashtags from the table using SQL and print them
        hashtag_counts_df = sql_context.sql("select hashtag, hashtag_count from hashtags order by hashtag_count desc limit 20")
#             finally:
        hashtag_counts_df.show()
    except:
        e = sys.exc_info()[0]
        print(e)
    finally:
        try:
            hashtag_counts_df.show()
        except:
            pass

# %%
# read data from port 9009
dataStream = ssc.socketTextStream("localhost",9009)
dataStream.pprint()
# split each tweet into words
words = dataStream.flatMap(lambda line: line.split(" "))
# filter the words to get only hashtags, then map each hashtag to be a pair of (hashtag,1)
hashtags = words.filter(lambda w: '#' in w).map(lambda x: (x, 1))
# adding the count of each hashtag to its last count
tags_totals = hashtags.updateStateByKey(aggregate_tags_count)
# do processing for each RDD generated in each interval
tags_totals.foreachRDD(process_rdd)
# start the streaming computation
ssc.start()
# wait for the streaming to finish
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2018-11-01 23:53:00
# -------------------------------------------
# I just need 5 seconds in @KoldKilla_ and @1Bandooo  closet. They outfits 😍😍😍😍.
# We here ‼️‼️‼️
# As could be predicted, Trump made NO POLICY ANNOUNCEMENT.
# We are so grateful to work with a diverse group of incredible #badass companies! Our clients are in manufacturing,… https://t.co/zKpGHw72Iy
# I gotta start bein selfish...GOT TO!!😤 cus everybody else sho is 😒
# Say she luv me jus to put my chain on ,
#
# ----------- 2018-11-01 23:53:00 -----------
# +-------+-------------+
# |hashtag|hashtag_count|
# +-------+-------------+
# |#badass|            1|
# +-------+-------------+
#
# +-------+-------------+
# |hashtag|hashtag_count|
# +-------+-------------+
# |#badass|            1|
# +-------+-------------+
#
# -------------------------------------------
# Time: 2018-11-01 23:54:00
# -------------------------------------------
# Just posted a photo @ Howland Township, Trumbull County, Ohio https://t.co/kHUaX4hbBN
# Malik Beasley working HARD on Tristan Thompson right now. I love that.
# Another three for Embiid! Harrell looked over to the Clippers bench like 'What am I supposed to do?'
# @tooprettykay___ @_DaeDoe Crack baby
# There’s a strong correlation b/w corruption and curbs on free speech and other civil liberties globally. 1 in 5 jou… https://t.co/S9QllEnXA9
# Drinking coffee while driving on a bumpy ass road is an extreme sport
# @bdh_photos FedEx it to me!!
# AMEN!!!!
# Apparently he is comfortable. @ Aldershot, Burlington https://t.co/MfYNKZbidX
# "I get judged on a daily basis...people don't like different." (Loud applause from audience)
# ...
#
# ----------- 2018-11-01 23:54:00 -----------
# +-------------------+-------------+
# |            hashtag|hashtag_count|
# +-------------------+-------------+
# |          #BeAVoter|            8|
# |              #love|            3|
# |#NationalAuthorsDay|            2|
# |        #HSOTScores|            2|
# |               #new|            2|
# |            #pdx911|            2|
# |            #Sabres|            2|
# |        #nevadacity|            2|
# |     #Annapropriate|            2|
# |     #NewProfilePic|            2|
# +-------------------+-------------+
#
# +-------------------+-------------+
# |            hashtag|hashtag_count|
# +-------------------+-------------+
# |          #BeAVoter|            8|
# |              #love|            3|
# |#NationalAuthorsDay|            2|
# |        #HSOTScores|            2|
# |               #new|            2|
# |            #pdx911|            2|
# |            #Sabres|            2|
# |        #nevadacity|            2|
# |     #Annapropriate|            2|
# |     #NewProfilePic|            2|
# +-------------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-01 23:55:00
# -------------------------------------------
# Very wise announcement. We need to retweet it.
# @fifty2twenty I swear I can pack the car for vacation or taking @rileygcarp to college like a Tetris World Champ.
# @ddsoffice @slah_zer Hadn’t thought of that, you could be right.
# @MarcPDumont lol I know
# H.S. Volleyball District Final
# Mio 14
# Hale 25
# End Set 2 (Hale leads 2-0)
# @EdwardLorn @ChasinTheStorm @sjgomzi @TWeirdling @MonstMashup @Grahamdoh @paulcook68 @SlasherTrash @coles84… https://t.co/KWLLARZzcQ
# @DesignationSix Damn good idea Secret!
# ...
#
# ----------- 2018-11-01 23:55:00 -----------
# +-------------------+-------------+
# |            hashtag|hashtag_count|
# +-------------------+-------------+
# |          #BeAVoter|           12|
# |              #love|            4|
# |#NationalAuthorsDay|            3|
# |               #NFL|            3|
# |               #job|            3|
# |           #hiring!|            2|
# |         #greenleaf|            2|
# |           #traffic|            2|
# |         #Halloween|            2|
# |        #HSOTScores|            2|
# +-------------------+-------------+
#
# +-------------------+-------------+
# |            hashtag|hashtag_count|
# +-------------------+-------------+
# |          #BeAVoter|           12|
# |              #love|            4|
# |#NationalAuthorsDay|            3|
# |               #NFL|            3|
# |               #job|            3|
# |           #hiring!|            2|
# |         #greenleaf|            2|
# |           #traffic|            2|
# |         #Halloween|            2|
# |        #HSOTScores|            2|
# +-------------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-01 23:56:00
# -------------------------------------------
# I prefer you at your best.
# I prefer you to be knowledgeable.
# I prefer you to be completely informed.
#
# In truth, you… https://t.co/oqwR2dMl9W
# Happiness doesn't come from being rich, nor merely from being successful in your career, nor by self-indulgence. ...
# bacon sounds so good rn
# @gustavoardz ice boy my favorite song 10/10
# @ammarontaula I will
# @jihoonbfs PLEASE
# ...
#
# ----------- 2018-11-01 23:56:00 -----------
# +---------------+-------------+
# |        hashtag|hashtag_count|
# +---------------+-------------+
# |      #BeAVoter|           15|
# |           #job|            7|
# |        #Hiring|            6|
# |     #CareerArc|            5|
# |       #traffic|            4|
# |        #pdx911|            4|
# |          #love|            4|
# |           #TBT|            4|
# |#TuaTagovailoa!|            3|
# |  #whatisschool|            3|
# +---------------+-------------+
#
# +---------------+-------------+
# |        hashtag|hashtag_count|
# +---------------+-------------+
# |      #BeAVoter|           15|
# |           #job|            7|
# |        #Hiring|            6|
# |     #CareerArc|            5|
# |       #traffic|            4|
# |        #pdx911|            4|
# |          #love|            4|
# |           #TBT|            4|
# |#TuaTagovailoa!|            3|
# |  #whatisschool|            3|
# +---------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-01 23:57:00
# -------------------------------------------
# Suit
# I love being on Twitter high because everything be funny asf 😭
# You flower, you feast
# @symphbetweeting Thank youuuu boo❤️❤️
# Asians be clean af
# Our #UrbanBestie rocking our flip tassel bag 🤗
# •
# •
# •
# •
# ...
#
# ----------- 2018-11-01 23:57:00 -----------
# +---------------+-------------+
# |        hashtag|hashtag_count|
# +---------------+-------------+
# |      #BeAVoter|           21|
# |        #Hiring|            9|
# |           #job|            9|
# |     #CareerArc|            6|
# |       #traffic|            5|
# |          #love|            5|
# | #TrueToAtlanta|            4|
# |#TuaTagovailoa!|            4|
# |  #Supernatural|            4|
# |        #pdx911|            4|
# +---------------+-------------+
#
# +---------------+-------------+
# |        hashtag|hashtag_count|
# +---------------+-------------+
# |      #BeAVoter|           21|
# |        #Hiring|            9|
# |           #job|            9|
# |     #CareerArc|            6|
# |       #traffic|            5|
# |          #love|            5|
# | #TrueToAtlanta|            4|
# |#TuaTagovailoa!|            4|
# |  #Supernatural|            4|
# |        #pdx911|            4|
# +---------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-01 23:58:00
# -------------------------------------------
# @joshtpm Josh, you may not like Assange, but this raises very serious issues about the freedom of the press. It's t… https://t.co/3J0BmQjrfn
# A year ago you said Dobby was your biggest regret give it a rest JK you already have more money than Santa Claus
# @phyll_indablank Is safe sex, when you have sex in a safe?
#
# Cause that sounds like it could be problem if ya don't have the combo. 😉
# Beat the box like a ass whooping
# @MaraRanger This is awesome!!
# “if you don’t sweat in your crack, you’re not doing it right”
# @HelenKennedy @CheriJacobus He Little Goebbels!! And he probably agrees w/‘everything Trump says . So basically a psycho ass kisser.
# The @GOP will make healthcare impossible to receive. They will penalize people for sickness. They will hoard wellne… https://t.co/ur2d1TDlkR
# ...
#
# ----------- 2018-11-01 23:58:00 -----------
# +--------------+-------------+
# |       hashtag|hashtag_count|
# +--------------+-------------+
# |     #BeAVoter|           25|
# |          #job|           12|
# |       #Hiring|           11|
# |      #traffic|            8|
# |       #Resist|            7|
# |    #CareerArc|            6|
# |#TrueToAtlanta|            5|
# |         #love|            5|
# |       #Repost|            5|
# |#StatueOfUnity|            5|
# +--------------+-------------+
# +--------------+-------------+
# |       hashtag|hashtag_count|
# +--------------+-------------+
# |     #BeAVoter|           25|
# |          #job|           12|
# |       #Hiring|           11|
# |      #traffic|            8|
# |       #Resist|            7|
# |    #CareerArc|            6|
# |#TrueToAtlanta|            5|
# |         #love|            5|
# |       #Repost|            5|
# |#StatueOfUnity|            5|
# +--------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-01 23:59:00
# -------------------------------------------
# Give me ass or give me death. Ok actually give me both.
# Juancho Hernangomez is a really nice young piece for the Nuggets who doesn’t get talked about enough due to injury last season
# Check out my brothers new banger !!! @DarrinBakerSAB x Dearly Departed (Prod. Berkli) by DarrinBakerM #np on… https://t.co/vFpilyVxHh
# Y’all Be Dating Some Bum Ass Bitches Fr
# I hate tests. With a passion.
# @I_am_Adrien It’s called lipliner
# presented without comment. https://t.co/b2AQLG74QQ
# @amz360 @ExSecular Even if it was compromise due post greed
# Why is he indulging in robotish politics now?!!!
# Wish h… https://t.co/gnqOqUKD4U
# ...
#
# ----------- 2018-11-01 23:59:00 -----------
# +--------------+-------------+
# |       hashtag|hashtag_count|
# +--------------+-------------+
# |     #BeAVoter|           31|
# |       #Resist|           25|
# |          #job|           14|
# |       #Hiring|           12|
# |      #traffic|            8|
# |    #CareerArc|            7|
# |#StatueOfUnity|            6|
# | #Supernatural|            5|
# |      #hiring!|            5|
# |   #HSOTScores|            5|
# +--------------+-------------+
#
# +--------------+-------------+
# |       hashtag|hashtag_count|
# +--------------+-------------+
# |     #BeAVoter|           31|
# |       #Resist|           25|
# |          #job|           14|
# |       #Hiring|           12|
# |      #traffic|            8|
# |    #CareerArc|            7|
# |#StatueOfUnity|            6|
# | #Supernatural|            5|
# |      #hiring!|            5|
# |   #HSOTScores|            5|
# +--------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-02 00:00:00
# -------------------------------------------
# College is me calling out of work ..... so I can still be at work at a tutoring session.... then clock right back i… https://t.co/aapLBjTboV
# I’m actually excited to go back to work tonight 🤑
# I need to shower real bad but instead I’m in line at a drive-thru getting fries.
# @HansNichols read this!
# @ScottHech Your friend needs help
# @PrissysTruth @realDonaldTrump The law needs to be changed!
# @jackiekeabler not only Coaches @BHSbroncosxc She also fills in as part time Volunteer and Athletic Director hopefu… https://t.co/YjmcPXs3yJ
# I’m tryna plan a ski trip, if you down let me know 🏂 #TistheSZN
# What has @CoolKid_GH done to you?
# Basic 🐰
# ...
#
# ----------- 2018-11-02 00:00:00 -----------
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |      #Resist|           43|
# |    #BeAVoter|           39|
# |         #job|           15|
# |      #Hiring|           12|
# |     #traffic|            8|
# |#RaiderNation|            7|
# |   #CareerArc|            7|
# |           #1|            6|
# |#Supernatural|            6|
# |      #LivePD|            6|
# +-------------+-------------+
#
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |      #Resist|           43|
# |    #BeAVoter|           39|
# |         #job|           15|
# |      #Hiring|           12|
# |     #traffic|            8|
# |#RaiderNation|            7|
# |   #CareerArc|            7|
# |           #1|            6|
# |#Supernatural|            6|
# |      #LivePD|            6|
# +-------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-02 00:01:00
# -------------------------------------------
# Big ole fizzacts 🤷🏽‍♀️
# @KFILE Sounds like Nebraska has its own ❄️
# So I decided that I won’t post stats after most games unless there involved in my takes. Checkout… https://t.co/TXJhHeF6DP
# @FCNightingale hello fred
# @ABC A bullet can go through a persons body. Rock cannot. What kind of seem similarity is that? It just goes to sho… https://t.co/Qrj3QW7pcn
# Why you giggling? @ Jacob K. Javits Convention Center https://t.co/QptBegjBqe
# Who sent me to go and give before daybreak deadline so? 😭😂
# @clockhuggez #guniwheel @ New York's 18th Congressional District https://t.co/cMfTWkSpqc
# i don’t need anyone. but itd be nice to be happy with you.
# Fisher: Yes sorry 😂
# ...
#
# ----------- 2018-11-02 00:01:00 -----------
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           50|
# |      #Resist|           43|
# |         #job|           17|
# |      #Hiring|           14|
# |#Supernatural|           10|
# |    #VoteBeto|           10|
# |#RaiderNation|            9|
# |           #1|            8|
# |     #traffic|            8|
# |   #CareerArc|            8|
# +-------------+-------------+
#
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           50|
# |      #Resist|           43|
# |         #job|           17|
# |      #Hiring|           14|
# |#Supernatural|           10|
# |    #VoteBeto|           10|
# |#RaiderNation|            9|
# |           #1|            8|
# |     #traffic|            8|
# |   #CareerArc|            8|
# +-------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-02 00:02:00
# -------------------------------------------
# @Alyssa_Howell_ It’s too cold for all that, Alyssa
# @cynthiamarieNL Some people right? Buy them for what they're worth and sell them for what they think they're worth. 🤑🤑🤑 🤣🤣🤣
# @SusanMillerMath And that was my attempt to keep it short!
# @Alynn7513 @GreerMcVay @MichaelAvenatti Ha, I apologize..all this time I was thought we were talking about Dr. Ford...
# Didn’t get to big time for @Brendan_Tobin! He must be hunting whales in his free time as well.
# @The_Trump_Train I sent a copy of the most recent letter of Pueblos sin Fronteras to you. We k ow there Are America… https://t.co/Zhi7Nk1eLs
# Whaaaaaaat😍
# scorpio season = trigger finger itching.
# @SamiiiSalas @Markeejoy we just said still dressing up on the 10th
# How do you prove to somebody you different from the rest?
# ...
#
# ----------- 2018-11-02 00:02:00 -----------
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           54|
# |      #Resist|           43|
# |      #Hiring|           17|
# |         #job|           17|
# |#Supernatural|           13|
# |#RaiderNation|           10|
# |   #CareerArc|           10|
# |    #VoteBeto|           10|
# |     #traffic|            9|
# |           #1|            9|
# +-------------+-------------+
#
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           54|
# |      #Resist|           43|
# |      #Hiring|           17|
# |         #job|           17|
# |#Supernatural|           13|
# |#RaiderNation|           10|
# |   #CareerArc|           10|
# |    #VoteBeto|           10|
# |     #traffic|            9|
# |           #1|            9|
# +-------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-02 00:03:00
# -------------------------------------------
# How about this?
# Teamwork is crucial to providing excellent patient care at Banner Health. Our team plays an important role in ensur… https://t.co/n53W37sEXB
# @JoeNeguse your opponent @barris4congress doesn’t care about preservation of our #WildHorses can you tell #CA-2 wha… https://t.co/9owdTf8tjL
# @LIBPrincipal @Shawnl8 @DTESPrincipal @theVAESP @ashleyfellis @ewilliams65 @MikeMartin956 @elainelayman @finn_teri… https://t.co/vkqznCcOvG
# @OHFam4Change According this @USATODAY article #marijuananews it should have never been illegal anyway it comes fro… https://t.co/tdTaQ3WQ2X
# Literally locked myself in my room all day today and just been crying and sleeping. If I didn’t have to pick up my… https://t.co/Zx2RjLwGaI
# 🔥🔥 @ New York, New York https://t.co/b11rC9EHHp
# @EASPORTS_MUT FIX YOUR TRASH BLOCKING SCHEMES AND STOP LETTING PEOPLE SPAM 2-4-5 MID BLITZ. YOU SHOULDNT GET PRESSU… https://t.co/Mr0567Kxdy
# Pervert
# you always wanted him
# ...
#
# ----------- 2018-11-02 00:03:00 -----------
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           59|
# |      #Resist|           43|
# |      #Hiring|           19|
# |         #job|           17|
# |#Supernatural|           16|
# |   #CareerArc|           12|
# |           #1|           10|
# |#RaiderNation|           10|
# |   #halloween|           10|
# |      #LivePD|           10|
# +-------------+-------------+
#
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           59|
# |      #Resist|           43|
# |      #Hiring|           19|
# |         #job|           17|
# |#Supernatural|           16|
# |   #CareerArc|           12|
# |           #1|           10|
# |#RaiderNation|           10|
# |   #halloween|           10|
# |      #LivePD|           10|
# +-------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-02 00:04:00
# -------------------------------------------
# This is such an awesome picture!
# @VTS_Seminary @GovernorVA @JerryBrownGov Christ does not allow the thief at the table that is how he is the Messiah… https://t.co/XUx04Iwz9K
# Day 305: Three years ago today, I met Jay. Life hasn’t been the same since and it keeps getting more wonderful ever… https://t.co/RuzRUd1Duq
# MY DAD BITCHES AND CRIES OVER THE ELECTRICITY BILL YET HE'S THE ONE WHO LEAVES EVERYTHING ON!!!
# Thats pretty dope they're going to have Goku in the Thanksgiving parade.
#  https://t.co/EmzlOITBiz
# @MGBrown Lol, really hope you get to hear one, there is nothing like it. I’d bet big money on you jumping though, haha
# Sick of eating left overs on your lunch break? Change it up by coming to JBTV for @reactpresents lunch break with… https://t.co/UC3UmMRjvU
# Love this man
# whoa whoa whoa . relax. say fuck em and T up shorty.
# ...
#
# ----------- 2018-11-02 00:04:00 -----------
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           64|
# |      #Resist|           43|
# |#Supernatural|           21|
# |      #Hiring|           19|
# |         #job|           19|
# |   #CareerArc|           13|
# |#RaiderNation|           12|
# |           #1|           11|
# |     #traffic|           11|
# |      #LivePD|           11|
# +-------------+-------------+
#
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           64|
# |      #Resist|           43|
# |#Supernatural|           21|
# |      #Hiring|           19|
# |         #job|           19|
# |   #CareerArc|           13|
# |#RaiderNation|           12|
# |           #1|           11|
# |     #traffic|           11|
# |      #LivePD|           11|
# +-------------+-------------+
#
# -------------------------------------------
# Time: 2018-11-02 00:05:00
# -------------------------------------------
# 🔴 Watch LIVE: President Donald Trump Holds MAGA Rally in Columbia, MO 11... https://t.co/Kk03QxS6X8 via @YouTube
# NOW!! #MAGA #VoteRED
# @KattyDinsmore Yeah but what sub type, what cookie WE GOTTA KNOW
# CAN’T WAIT FOR CHRISTMAS
# @gnrlyhd_ Damnit Vern I miss you
# @realDonaldTrump Hope your note taker took good notes this afternoon so you might remember todays LIES for tonights… https://t.co/y8ZvY7WNqA
# @ChrisMurphyCT I hate that @POTUS 45  IS A  LIAR - THE  WHOLE @GOP  LIES!
# Classic New York Irish...(reuben) 🍀🍀🍀🍀🍀 @ Peggy Kinnane's Irish Restaurant &amp; Pub https://t.co/Fff4KgsbS9
# Red Wave!
# The Clintons are the biggest hypocrites
# ...
#
# ----------- 2018-11-02 00:05:00 -----------
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           68|
# |      #Resist|           43|
# |#Supernatural|           23|
# |         #job|           21|
# |      #Hiring|           19|
# |   #CareerArc|           13|
# |     #traffic|           12|
# |#RaiderNation|           12|
# |   #halloween|           12|
# |      #LivePD|           12|
# +-------------+-------------+
#
# +-------------+-------------+
# |      hashtag|hashtag_count|
# +-------------+-------------+
# |    #BeAVoter|           68|
# |      #Resist|           43|
# |#Supernatural|           23|
# |         #job|           21|
# |      #Hiring|           19|
# |   #CareerArc|           13|
# |     #traffic|           12|
# |#RaiderNation|           12|
# |   #halloween|           12|
# |      #LivePD|           12|
# +-------------+-------------+
