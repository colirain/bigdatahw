# %%
import socket
import sys
import requests
import requests_oauthlib
import json

# %%
# Replace the values below with yours
ACCESS_TOKEN = '1048005627816169473-5tJdLYafXOfCUaHWDFtcqjCvBRdU90'
ACCESS_SECRET = 'iIQRVbZTN625Zn1xRPwDKkOH8Mk4xqrAEn8ICb39CTIeY'
CONSUMER_KEY = 'iTrUDoKffZNLfSYvc9ctDXGJZ'
CONSUMER_SECRET = 'XEuXkw8AesuyxYaiPG7CSI1r0IhuXhcN8vvTYyimrCoAvMShU4'
my_auth = requests_oauthlib.OAuth1(CONSUMER_KEY, CONSUMER_SECRET,ACCESS_TOKEN, ACCESS_SECRET)

# %%
def get_tweets():
    url = 'https://stream.twitter.com/1.1/statuses/filter.json'
    query_data = [('language', 'en'), ('locations', '-130,-20,100,50'),('track','#')]
    query_url = url + '?' + '&'.join([str(t[0]) + '=' + str(t[1]) for t in query_data])
    response = requests.get(query_url, auth=my_auth, stream=True)
    print(query_url, response)
    return response

# %%
def send_tweets_to_spark(http_resp, tcp_connection):
    for line in http_resp.iter_lines():
        try:
            full_tweet = json.loads(line)
            tweet_text = full_tweet['text']
            print("Tweet Text: " + tweet_text)
            print ("------------------------------------------")
            tcp_connection.send(tweet_text + '\n')
        except:
            e = sys.exc_info()[0]
            print("Error: %s" % e)

# %%
TCP_IP = "localhost"
TCP_PORT = 9009
conn = None
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.bind((TCP_IP, TCP_PORT))

# %%
s.listen(1)
print("Waiting for TCP connection...")
conn, addr = s.accept()
print("Connected... Starting getting tweets.")
resp = get_tweets()
# send_tweets_to_spark(resp, conn)


http_resp = resp
tcp_connection = conn
for line in http_resp.iter_lines():
    try:
        full_tweet = json.loads(line)
        tweet_text = full_tweet['text']
        print("Tweet Text: " + tweet_text)
        print ("------------------------------------------")
        tweet_text += '\n'
        tcp_connection.send(tweet_text.encode())
    except:
        e = sys.exc_info()
        print("Raise an Error:")
        print(e)
# Out:
# Waiting for TCP connection...
# Connected... Starting getting tweets.
# https://stream.twitter.com/1.1/statuses/filter.json?language=en&locations=-130,-20,100,50&track=# <Response [200]>
# Tweet Text: Legendary. Tell Foe congrats on the Yae
# ------------------------------------------
# Tweet Text: Can you recommend anyone for this #job in #Bangalore? https://t.co/8LDsh6HBKQ #Engineering #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: welcome to bob’s burgers 🍔 @ Phoenix, Arizona https://t.co/uqO5J2s7uW
# ------------------------------------------
# Tweet Text: @amyycummings I LOVE YOU😭😭❤️❤️❤️
# ------------------------------------------
# Tweet Text: I mf hate golden state
# ------------------------------------------
# Tweet Text: @gregkash 50 years of this, anyway.
# ------------------------------------------
# Tweet Text: Mother Nature ain’t gunna let you smash bro
# ------------------------------------------
# Tweet Text: "Quotes by yours truly"
# Swipe to choose your best✔
#
# The future of medicine lies in the hands of our generation! @ C… https://t.co/jKI0JqhC3f
# ------------------------------------------
# Tweet Text: The struggle to take a family photo is real.
# ------------------------------------------
# Tweet Text: Did the pelicans not sell out ? How does a team with Anthony Davis not sell out every single home game? Guy is unreal
# ------------------------------------------
# Tweet Text: Dead ass 😩😂
# ------------------------------------------
# Tweet Text: Who knoweth, getteth his firm base, he becometh the master of food and its eater, great in progeny, great in cattle… https://t.co/YPCZnscglx
# ------------------------------------------
# Tweet Text: +infinity
# Given his penchant to appear as 60 old might not happen aa well
# ------------------------------------------
# Tweet Text: Kyrie been “ jellying “ before it even got popular lol
# ------------------------------------------
# Tweet Text: me. i needed to hear this.
# ------------------------------------------
# Tweet Text: Great Win @warriors👏!!! Dam I know the @jazz feel real salty now😂!!! @NBCSWarriors @WarriorsPR @warriorsworld… https://t.co/eoptOYgJa7
# ------------------------------------------
# Tweet Text: People are so weak minded🐀
# ------------------------------------------
# Tweet Text: i lost my airpod whilst jamming out to big time rush :/
# ------------------------------------------
# Tweet Text: I just wish I had somebody wit a strong mindset to build wit and help me get tf outta here .. 😣
# ------------------------------------------
# Tweet Text: They call my penis Dick Flair
# ------------------------------------------
# Tweet Text: @brfharbans @Kuvalayamala Great point Sir. I was wondering why I can't become a Supreme Court lawyer with immediate… https://t.co/o8jjENuFDS
# ------------------------------------------
# Tweet Text: @Alyssa_Milano @FoxNews Not one word about the rapist Bill Clinton and his new accuser or Keith Ellison but good on… https://t.co/CgM3r0mNxH
# ------------------------------------------
# Tweet Text: Hasn’t West Sham been relegated already? 🤷🏼‍♂️
# ------------------------------------------
# Tweet Text: Hello! :-)
# ------------------------------------------
# Tweet Text: @saskman100 @pretyh8tmachine @debiowens @tymanmayo Wait till you figure out how much they stole....
# ------------------------------------------
# Tweet Text: I can do everything right and give a nigga everything he want , and still end up left in the dark .
# ------------------------------------------
# Tweet Text: my dad doesn’t even call to tell me happy bday &amp; avoids me all day /:
# ------------------------------------------
# Tweet Text: up watching the dave chappelle show
# ------------------------------------------
# Tweet Text: I hate the way weed do me 😂😂
# ------------------------------------------
# Tweet Text: mY sOnS......... mEe mIChAEl nAG https://t.co/A8TsoDfoA4
# ------------------------------------------
# Tweet Text: @RadhamohanBJP Dear sir when are you going to supply sexed semen of gir sahiwal tharparkar etc to farmers in order… https://t.co/VunbAEmyKO
# ------------------------------------------
# Tweet Text: @MayaLemaire I feel this so much and have been faced with the same dilemma 🧐...honestly, I’ve begun to slowly unfol… https://t.co/EXM3b6hVvT
# ------------------------------------------
# Tweet Text: Indeed. 🎯
# ------------------------------------------
# Tweet Text: @HTC_Shakiia any fun plans this weekend? 🤔
# ------------------------------------------
# Tweet Text: I know somebody’ll love me before yo dog ass do💯
# ------------------------------------------
# Tweet Text: Football weekend https://t.co/EbKk0sc5WT
# ------------------------------------------
# Tweet Text: @beverage_cart @bizarchive @tourphish Mexican Cousin while flying across the stage on scooters 😈😈😈
# ------------------------------------------
# Tweet Text: Me.
# Today.
# Outside the bandroom, by the yellow jacket infested, blue POS trailer.
# To the left of a sousaphone.… https://t.co/fOeV9pWTqb
# ------------------------------------------
# Tweet Text: @IzvarinCamille I’m so glad you dropped by to visit!
# ------------------------------------------
# Tweet Text: This hair so long😩😩
# ------------------------------------------
# Tweet Text: @CameronCrowe @Neilyoung Awesome! When’s the release?
# ------------------------------------------
# Tweet Text: @realDonaldTrump I thought that was Lyin’ Ted as many times as you called him that.
#
# The REAL lightweight is Lyin’… https://t.co/ci0cNeatIs
# ------------------------------------------
# Tweet Text: Plus this rain ain't helping.
# ------------------------------------------
# Tweet Text: System of a Down @ T-Mobile Arena https://t.co/MwI51OZqDE
# ------------------------------------------
# Tweet Text: @amtvmedia Hi Chris good day! I agreed with you but the ppl not understand that the crypto will be a real freedom f… https://t.co/igkrN4vt29
# ------------------------------------------
# Tweet Text: Sis don't duck if the shots don't apply https://t.co/9LtITbitOr
# ------------------------------------------
# Tweet Text: Mainey... lol
# ------------------------------------------
# Tweet Text: Oh hell man foo😂
# ------------------------------------------
# Raise an Error:
# (<class 'json.decoder.JSONDecodeError'>, JSONDecodeError('Expecting value: line 1 column 1 (char 0)',), <traceback object at 0x7f37afe265c8>)
# Tweet Text: Working out with my nephews was the best shit
# ------------------------------------------
# Tweet Text: life is really beautiful
# ------------------------------------------
# Tweet Text: @45Eric4Trump @bighoov2023 @RedheadLadyNY @American2b @Dbargen @NiteMare817 @wydoin @buzzman888 @Trump454545… https://t.co/twCCDA6cAo
# ------------------------------------------
# Tweet Text: My lil small car would’ve been covered 😭😭😭😭
# ------------------------------------------
# Tweet Text: @CeceRey Such poetic. lol
# ------------------------------------------
# Tweet Text: The city’s first business block watch program is starting in West Seattle @komonews #KOMONews
# ------------------------------------------
# Tweet Text: @THUG_LIFE
# •••
# "Everyone Wants Happiness No One Wants Pain But U Can't Make A Rainbow Without A Little Rain"
# Mr.13👑 https://t.co/wfpDKCvMgO
# ------------------------------------------
# Tweet Text: @Rumblewar @AXSTV @AXSTVFights @BarbiHayden @holidead @HoganKnowsBest3 @GiseleShaw08 @Ray_lyn @w_nightingale_… https://t.co/rmehOOVpEg
# ------------------------------------------
# Tweet Text: I never listen to people on social media, because most of you aren’t who you say you are.
# ------------------------------------------
# Tweet Text: @Mavadar @WalshFreedom Amen!!
# ------------------------------------------
# Tweet Text: man how am i just now find out about what happened to my mom? i'm so angry. i hope these guys get what they deserve.
# ------------------------------------------
# Tweet Text: # Releasing on NOVEMBER 2ND # https://t.co/eYRTW0654K
# ------------------------------------------
# Tweet Text: @youfunnyJO Where you at though???
# ------------------------------------------
# Tweet Text: Down 16 at halftime but the Warriors win it 124-123 against the Utah Jazz Jonas with a big basket against his forme… https://t.co/UzwSwg891n
# ------------------------------------------
# Tweet Text: Shoutout to Aunt @jessicaamorann for doing Gracelyns makeup tonight ❤️ she loved it so much 😭
# ------------------------------------------
# Tweet Text: @gooodbye Hello
# ------------------------------------------
# Tweet Text: • o o t d •
#
# •
#
# Bruised rib cage, skinned knees, shins, elbows, palms ... but...some swagger on a Friday. Nashvill… https://t.co/90YZHzimoo
# ------------------------------------------
# Tweet Text: @RealDicPleaser Fine chocolate ass
# ------------------------------------------
# Tweet Text: @Abdulaziz_Hmadi 1. google keep
# 2. google docs
# 3. google maps
# 4. 1password
# ------------------------------------------
# Tweet Text: @AntonioSabatoJr I had to read this 3 times before I saw the word “not” 😳😂 #AntonioSabato #vote #redcali
# ------------------------------------------
# Tweet Text: Vertigo by Khalid is beautiful oh my geezus
# ------------------------------------------
# Tweet Text: @GLOCKInc laugh in our face? https://t.co/OXMnPe6ypL
# ------------------------------------------
# Tweet Text: Thanks for the invite I’m having a great time
# ------------------------------------------
# Tweet Text: I’m gonna cry so hard during every single second of my concert I’m so ready ||-//
# ------------------------------------------
# Tweet Text: As easy as you like
# ------------------------------------------
# Tweet Text: Ready for TRCN exams So Help me God amen
# ------------------------------------------
# Tweet Text: @RajapaksaNamal Thanks 🙂 but you left to Tangalle middle of the night without cutting the cake 😬
# ------------------------------------------
# Tweet Text: Doing ads en español to own the libs
# ------------------------------------------
# Tweet Text: This is Pakistan's Punjabi elite. The woman was stopped by cops for driving without license plates. Her reaction il… https://t.co/hBB1QzQsQ3
# ------------------------------------------
# Tweet Text: never fails that guys don’t see what they’re doing wrong
# ------------------------------------------
# Tweet Text: How Christian drives. Lol old blind girl. https://t.co/yzdAqm0AvY
# ------------------------------------------
# Tweet Text: Trying so hard not to break in this club
# ------------------------------------------
# Tweet Text: @IndiaToday @sunilJbhat Local administration is accountable solely for their lacklustreness.
# ------------------------------------------
# Tweet Text: This is the first time since November 7, 1990 that a team scored 81+ in a half and lost. Denver scored 90 in the fi… https://t.co/6lx0e83D0N
# ------------------------------------------
# Tweet Text: If you happen to do to Saudi embassy. DONOT GET INTO A FIST FIGHT. You might get hack sawed.
# ------------------------------------------
# Tweet Text: I need to see a bartender like rn
# ------------------------------------------
# Tweet Text: @TheEllenShow Looking forward to it😁
# ------------------------------------------
# Tweet Text: @_RoseAnnSapia So pumped to read this!
#
# I wanna see a battle of the third base men square up — Shaw vs Devers.
#
# Pl… https://t.co/XrraU6AgvP
# ------------------------------------------
# Tweet Text: Spotted this electric scooter by @ScootNetworks when walking down the roads of San Francisco, CA.
#
# Apparently this… https://t.co/U99x30Bu5G
# ------------------------------------------
# Tweet Text: @Shannon96574094 Hey Liberal's, do you know who else want's I.C.E. gone?
#
#                      Drug cartels… https://t.co/OMt1UvhPBq
# ------------------------------------------
# Tweet Text: I don't even vent nomo
# ------------------------------------------
# Tweet Text: Why won't you think it's a polytechnic when you don't know how to read simple English "Federal University of Techno… https://t.co/kKqKMI0cyA
# ------------------------------------------
# Tweet Text: I’m paying for this in the morning
# ------------------------------------------
# Tweet Text: just imagine if someone gave a fuck
# ------------------------------------------
# Tweet Text: i write some Good shit on my finsta but when i open my journal w a pen in my hand i struggle to form a sentence Smh
# ------------------------------------------
# Tweet Text: Damn I really stayed in tonight
# ------------------------------------------
# Tweet Text: @historylvrsclub Leonardo Da Vinci could not have
# Created a Stronger Image of the
# BACKBONE of The LED ZEPPELIN… https://t.co/CRXRu88u4A
# ------------------------------------------
# Tweet Text: Utah Jazz took a big “L” on a game winner by a dude they dropped in the summer ....😂 wow
# ------------------------------------------
# Tweet Text: I don’t watch fox business because of her
# ------------------------------------------
# Tweet Text: @LarryBeilABC7 Hopefully I win mega millions if I said Jerebenko
# ------------------------------------------
# Tweet Text: @JudoKnowMeTho happy birthday bf I love you so much!! I wish I was there 😢😭 but I know you gon be turnt 😂🎉🎉
# ------------------------------------------
# Tweet Text: @thelibraleo @William_J_Hurst @wikileaks No. Not exactly that. I didn't say USA couldn't get by. Basically we would… https://t.co/1NX1102ELa
# ------------------------------------------
# Tweet Text: @yungtreebranch @DeeMartin_ @DeuceThomas You are very smart.
# ------------------------------------------
# Tweet Text: If you're drunk in a car at night with an aux cord I can only hope you have the requisite rap knowledge to make the most of the trip
# ------------------------------------------
# Tweet Text: @John_Kass @americageddon @chim0m @KashJackson2018 But when #EarlyVoting began in McLean County last month, my choi… https://t.co/s2lhRAQSiP
# ------------------------------------------
# Tweet Text: @realDonaldTrump The truth is NONE of our leaders give a crap about you and me. They only care about selling their… https://t.co/GkjlAQYV6j
# ------------------------------------------
# Tweet Text: Nothing I love more than riding in the rain and getting all muddy https://t.co/P6KkM7kfSt
# ------------------------------------------
# Tweet Text: Not really lol
# ------------------------------------------
# Tweet Text: 'shelter', 'cyclones' &amp; 'prone' are now trending in #Hyderabad
#
# https://t.co/Q7JjHpbJMx https://t.co/2BKQ852PRp
# ------------------------------------------
# Tweet Text: Drunk hiccups can fuck right off
# ------------------------------------------
# Tweet Text: y’all don’t give a fuck about the wrong things. and it’s so scary.
# ------------------------------------------
# Tweet Text: @NovasIdeiasKadu @mariodefarias_ @jairbolsonaro Chegou a hora da viradaaaaaaa !!!
# VOTE 1️⃣2️⃣ RN  #oRNtemjeito VOTE… https://t.co/CfdSMNoXFC
# ------------------------------------------
# Tweet Text: temperature down 74°F -&gt; 65°F
# humidity up 52% -&gt; 55%
# wind 7mph -&gt; 6mph
# ------------------------------------------
# Tweet Text: @SavannaStone01 @WeAreGloryPro Ur nuts! I love it 🔥👌🏼
# ------------------------------------------
# Tweet Text: @BoxWet Welcome
# ------------------------------------------
# Tweet Text: Very interesting👇
# ------------------------------------------
# Tweet Text: When a tear rolls down yah cheek and you can’t remember if you yawned or yah soul crying..
# ------------------------------------------
# Tweet Text: goodnight. https://t.co/vf4qWkRFxV
# ------------------------------------------
# Tweet Text: everytime I pick up #unexpectedcrossroads  &amp; I see author @Blossom_Carter_ I get so excited because I’m so proud of… https://t.co/o1GO1YKAlW
# ------------------------------------------
# Tweet Text: Fool me one time shame on you, fool me twice can’t put the blame on you!
# ------------------------------------------
# Tweet Text: I’m not mad anymore :)
# ------------------------------------------
# Tweet Text: God has really been testing my  strength lately. Feel like I’ve lost quite a lot lately but I mustn’t give in. Thro… https://t.co/Ymyx4HZQ72
# ------------------------------------------
# Tweet Text: Our venue the Telefonica tower Diagonal 00 is ready.💪
# Doors open at 08.30, see you there! https://t.co/VrVxquYlnV
# ------------------------------------------
# Tweet Text: Can't say I don't agree... Some awful phrases up in der.
# ------------------------------------------
# Tweet Text: Motion to open a Chimy's in El Paso?
# ------------------------------------------
# Tweet Text: i’m going from Tame Impala straight to Michael Jackson. i don’t know what kind of night it is, but it’s just that night.
# ------------------------------------------
# Tweet Text: i'm independent, but i understand what the meaning of interdependence is when in a relationship.
# ------------------------------------------
# Tweet Text: @sergiobugarin_ Thank you❤️❤️
# ------------------------------------------
# Tweet Text: @ZhouFerrari @Sandra24Jan @Fan5Vettel @Vetteleclerc Don’t expect a reply now...😂
# Bucket of excuses these Hamilton f… https://t.co/YNPHkG8qru
# ------------------------------------------
# Tweet Text: Dis me always https://t.co/VQ6Ieuuu5E
# ------------------------------------------
# Tweet Text: Jayson Tatum WILL BE an all time great ‼️ you heard it here first
# ------------------------------------------
# Tweet Text: Dubai deployed its cutting-edge technology by offering blockchain-based payment solution to its residents. https://t.co/KOcifY1uoM
# ------------------------------------------
# Tweet Text: I concur!
# ------------------------------------------
# Tweet Text: @S4SHATEED I wanna see 👀
# ------------------------------------------
# Tweet Text: @DJSCHEME_ @THESLUMPGOD @JuiceWorlddd Where
# ------------------------------------------
# Tweet Text: @violadavis = #BlackGirlMagic
# #violadavis #tgit #howtogetawaywithmurder @ Newark, New Jersey https://t.co/uKf1LlAnav
# ------------------------------------------
# Tweet Text: @EliasGalileo @Phil_Lewis_ And those that support him are lowlife—the bottom feeders of the USA. The leeches that d… https://t.co/XHgyfka5Or
# ------------------------------------------
# Tweet Text: @SoulsBourneMarx I do my best 😉
# ------------------------------------------
# Tweet Text: I love her and her damn sailor outfit
# ------------------------------------------
# Tweet Text: You obviously need some brains bc none of us “democrats” are trying to silence free speech
# ------------------------------------------
# Tweet Text: feel like shit just want pizza crust
# ------------------------------------------
# Tweet Text: Happy Puja!
# #photo #photos #pic #pics #photography #instapic #picture #pictures #snapshot #art #beautiful… https://t.co/6zpH5JHIQb
# ------------------------------------------
# Tweet Text: @tyranoelle3 Ctfuuu, hell yeahh !
# ------------------------------------------
# Tweet Text: @ecunupe @Hikeabike902 @jemelehill It is real! Unbelievable but real.
# ------------------------------------------
# Tweet Text: man that 500 mil would’ve been nice
# ------------------------------------------
# Tweet Text: A slight smile for my Timeline ❤️😍🤞🏾 https://t.co/ysEJcaEOyB
# ------------------------------------------
# Tweet Text: Me checking to see #NLCS going to Game 7. https://t.co/GNytzTkmJo
# ------------------------------------------
# Tweet Text: you just had to flip boy, @Bfeazy24? lol
# ------------------------------------------
# Tweet Text: @trinalanay2pt0 My dad stayed playing that song when I was younger I had to do his work justice at some point in my life lmao
# ------------------------------------------
# Tweet Text: I took a quiz without studying and got a 54/50 so I was confident enough to go ahead and take the exam without stud… https://t.co/dRcZ1I7FlK
# ------------------------------------------
# Tweet Text: Cough* cough* co-Ed 🤧🤧😉
# ------------------------------------------
# Tweet Text: Awesome job by Tiger Marching Pride and the Senior Walk tonight after the game! #OnwardTigers #GilbertGoldenHour https://t.co/uaZOnqOPxD
# ------------------------------------------
# Tweet Text: Pen cap. In my ear. Because my g.m. Has a full sleeve. And my d.m. Has a 3/4 sleeve. And I will not be told I can’t… https://t.co/jzhzamj91p
# ------------------------------------------
# Tweet Text: @elonmusk @BoredElonMusk Hey Elons! Love the brand, can you help me pay off my student loans? Only about 11k to go.… https://t.co/FrOWwjrsD9
# ------------------------------------------
# Tweet Text: I would say things are going well for me but not as well as the time someone told me I remind them of Gwen Grayson from Sky High
# ------------------------------------------
# Tweet Text: How about protecting the most vulnerable populations in Central American fleeing from unspeakable poverty, death th… https://t.co/itMjjQXpY6
# ------------------------------------------
# Tweet Text: @_chiisom It was the same situation on Karaye camp, Kano where I camped. Some soldiers helped smuggle-in some vodka… https://t.co/EkhmnnAXCl
# ------------------------------------------
# Tweet Text: Can we just talk about how insane elephants are...
# ------------------------------------------
# Tweet Text: im fucking dead theres no way this is real life
# ------------------------------------------
# Tweet Text: With the new day comes new strength and new thoughts!
# #quoteoftheday
# ------------------------------------------
# Tweet Text: My gals 💜 https://t.co/R2Pw3dk07s
# ------------------------------------------
# Tweet Text: It’s 🔥🔥🔥 bro !!
# ------------------------------------------
# Tweet Text: My dog is a nugget, my cat is a nugget, Dennis is a nugget, IM a nugget... we’re a lil four piece fam🙃 #InsertNuggetEmoji
# ------------------------------------------
# Tweet Text: Finally heading to bed.
# ------------------------------------------
# Tweet Text: Thanks anyway for your worthless offer. Just trying to publicly save face without actually doing what's right, eh?… https://t.co/AOjPEDNrox
# ------------------------------------------
# Tweet Text: @DougDavidsonYR you were the reason I watched Y&amp;R
# ------------------------------------------
# Tweet Text: @krumm_g @realDonaldTrump Golden Gate National Cemetery
# ------------------------------------------
# Tweet Text: I really need a back rub
# ------------------------------------------
# Tweet Text: 10 hours of sleep.
# Missed around 5 phone calls. Took half an hour to go through all notifications.
#
# Damn so many th… https://t.co/l7ikGauXQK
# ------------------------------------------
# Tweet Text: @TammyKOMO @komonews Very interesting @TammyKOMO you should tell that to @SethonKOMO and mrs #kellykoopmanskomo.
# ------------------------------------------
# Tweet Text: All this time we spent slowing it down, now you wanna go fast, now I go fast.
# ------------------------------------------
# Tweet Text: as much as this hurts 💔 I can’t do nothing but wish you the best &amp; i hope someday someone’s makes you happy like I never did....
# ------------------------------------------
# Tweet Text: @indierod Reductio ad triples
# ------------------------------------------
# Tweet Text: Geez UNLV. Maybe cut the Steve Perry/Journey song so Air Force can sing their alma mater? Very disrespectful. These… https://t.co/JaolprkGpj
# ------------------------------------------
# Tweet Text: @franchescaaa12 thank you😭❤️
# ------------------------------------------
# Tweet Text: With all desperation of seeking attention and recognition, I won't be surprised if heckling happens. @RailaOdinga i… https://t.co/A6x7nucQJZ
# ------------------------------------------
# Tweet Text: honestly i have some of the most beautiful friends in my life like y’all are gorgeous inside and out. thank you for… https://t.co/xVZLC61kCk
# ------------------------------------------
# Tweet Text: @jaylonharper00 @ErnestHagins crazy, and that boy Ern can’t answer the phone for nothin
# ------------------------------------------
# Tweet Text: @Real_Auntie @leeleeb50 She is a scumbag.
# ------------------------------------------
# Tweet Text: Chester Watson is so talented
# It blows my mind
# ------------------------------------------
# Tweet Text: My jazz clearly the second best team in the west. Win or lose y’all know it
# ------------------------------------------
# Tweet Text: @sherryontopp paaji why its always @RailMinIndia is always being blamed... When these ppl whose attitude is chalta… https://t.co/KTBH096xhD
# ------------------------------------------
# Tweet Text: Well that doesn’t make me feel good https://t.co/FFkG3Fnt5a
# ------------------------------------------
# Tweet Text: @Ezekiels_Call @jacobpigott @RealCandaceO Open my eyes.. I see a guy who admitted to cheating on his wives and taxe… https://t.co/ethc2hEKbX
# ------------------------------------------
# Tweet Text: That moment of intense anxiety when you are driving and cant find your vape...😓 #ifoundittho
# ------------------------------------------
# Tweet Text: You a t-Rex wtf
# ------------------------------------------
# Tweet Text: Book Signing Today: The Purple Bird by Samar Al-Barghouthi
# Saturday, 20th October: 4-5:00 pm
#
# Join Dr Samar Al-Barg… https://t.co/MCoLNpw7vs
# ------------------------------------------
# Tweet Text: I can’t wait to be in bed
# ------------------------------------------
# Tweet Text: God bless every earth worm .
# ------------------------------------------
# Tweet Text: I don’t feel like getting sweaty on Fortneezy.  Gonna smoke and kill Nazis
# ------------------------------------------
# Tweet Text: I’m so excited because finally someone is gonna be a bad ass bitch like wow my fucking heart
# ------------------------------------------
# Tweet Text: The fact that no one has replied to me 😭
# ------------------------------------------
# Tweet Text: @thearticle133 @JackPosobiec @KurtSchlichter My child is autistic and I would give my life for her but at no day, t… https://t.co/hWZBGQxyWb
# ------------------------------------------
# Tweet Text: My old job is getting SUED and I ended up getting involved. Ain’t God GOOD???
# ------------------------------------------
# Tweet Text: Join the General Electric team! See our latest #job opening here: https://t.co/7lHDtv8Ztm #CustomerService #Mumbai #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Two years ago I was an asshole for believing in trump. Bitter debates. Although now it’s basically temperament seem… https://t.co/rhxPGgKiv3
# ------------------------------------------
# Tweet Text: I voted for my favorite nominees in the 2019 Fan Vote presented by Klipsch Audio #RockHall2019  https://t.co/WnKsYCRqGK
# ------------------------------------------
# Tweet Text: Blessed to hear such energising words from shri N. Gopalakrishnan sir,founder of Institute of Indian Heritage https://t.co/yjqGnl1cIb
# ------------------------------------------
# Tweet Text: For More Tips on the Moving and Delivery Services, Follow This Page! https://t.co/c6Hh8jO8R8
# ------------------------------------------
# Tweet Text: yes boo..ctfu
# ------------------------------------------
# Tweet Text: I have a love in my life. It makes me stronger than anything you could ever imagine.
# ------------------------------------------
# Tweet Text: @brichellepena First ever game winner
# ------------------------------------------
# Tweet Text: @AIIAmericanGirI @realDailyWire After 3 days opening weekend here in Madison Wisconsin it was dropped from theaters.
# Very liberal city.
# ------------------------------------------
# Tweet Text: If you got a loyal faithful man YOU did not make him that way HE did that's HIS choice to be a good man just like b… https://t.co/kZKolCx78i
# ------------------------------------------
# Tweet Text: @Toddhill_9 This guy needs a scholarship in better competition but keep getting stronger and faster Young fella
# ------------------------------------------
# Tweet Text: Bruh did Steph really just ...  OKAY IM GOING TO SLEEP.... someone come get they girl....
# ------------------------------------------
# Tweet Text: @Tweet__annie Im with you on that one!!!! Just that if the dodgers lose va ser una sad peda😫😂
# ------------------------------------------
# Tweet Text: I wanna throw away my phone
# ------------------------------------------
# Tweet Text: Homecoming may be the last time I party, shit lame
# ------------------------------------------
# Tweet Text: My dad is a freemason and is a great man so I'm excited to finally watch Netflix's freemasonry documentary
# ------------------------------------------
# Tweet Text: Brad has the most beautiful hands I’ve ever seen
# ------------------------------------------
# Tweet Text: Swear humans don’t deserve the love animals have to offer!
# ------------------------------------------
# Tweet Text: U threw away all our pictures, but you still got the memories so what’s the difference?
# ------------------------------------------
# Tweet Text: @Ismahawk I don't see why everyone is getting so upset, they are doing this for a reason. Three words, Heroes for Hire.
# ------------------------------------------
# Tweet Text: @Thomas1774Paine Not transphobic bigots at all. Just how do you square a man competing with all women?  Just realistic.
# ------------------------------------------
# Tweet Text: i’m just tried of being sad tbh
# ------------------------------------------
# Tweet Text: @NathanLerner @joncoopertweets @BetoORourke Town Meeting allowed concerned citizens to ask “tough” questions. Beto… https://t.co/oGgaC6xTCv
# ------------------------------------------
# Tweet Text: I’m living.....that’s something to thank God for
# ------------------------------------------
# Tweet Text: @BHypeRs_ About time you admit it.
# ------------------------------------------
# Tweet Text: i can't wait to watch a drake  documentary i know it's gonna happen
# ------------------------------------------
# Tweet Text: @HollylobsterL Yeah me too where can I meet you baby Miss Lobster! Steven 😎👈👉🐺🌹💘😘🖐️ no 🐂
# ------------------------------------------
# Tweet Text: A monkey may be in office but the sports field for real pays this shit no mind. America has a standard to live up t… https://t.co/97rdmGWePU
# ------------------------------------------
# Tweet Text: I am blowing off the real bone I have to pick with Trump and its supporting mixed martial arts that's like mixing c… https://t.co/1rA5AUtkfh
# ------------------------------------------
# Tweet Text: Oh I remember you out there ALL THE TIME!!  I even had to cut the damn grass because You were busy with that dang b… https://t.co/Y4wRkfTWOx
# ------------------------------------------
# Tweet Text: @dwhit718 @BlakeRoller Shut up Dylan.
# ------------------------------------------
# Tweet Text: Tonight!!! I just arrived come say Hi!! #Repost @mexibelle28
# ・・・
# Oct 19th I'll be go go dancing at the #westcoast p… https://t.co/L3gK98Z5w1
# ------------------------------------------
# Tweet Text: @AgentM @Daredevil Just binge watched DD season 3!  AWESOME!! Totally floored by it! Truly an immersive experience!… https://t.co/fTWwWADrvH
# ------------------------------------------
# Tweet Text: @FaithAlakas You are a true African iwe. 😂
# ------------------------------------------
# Tweet Text: @dianav__ happy birthday ❤️🖤
# ------------------------------------------
# Tweet Text: just want to thank both @iEliteShot for letting me be apart of his community and also my brother @mess_loc who intr… https://t.co/XE4Va4cn76
# ------------------------------------------
# Tweet Text: Ppl swear they know why they want till they actually get it
# ------------------------------------------
# Tweet Text: @joeagleason @ray_zepeda1 @abc13houston @abc13sports @Speed11Coach this my boy I been telling you about
# ------------------------------------------
# Tweet Text: you think he’s not cheating on you? well he is. you think he will take care of your kid and not his own, you’re wro… https://t.co/7sWLIMwhQe
# ------------------------------------------
# Tweet Text: Ron Rafael Shimshilashvili &amp; Marger Sealey at the 2018 #LaMusaAwards #MusaAwards #ronrafael #ronrafaels… https://t.co/fNYFi7LubC
# ------------------------------------------
# Tweet Text: Childhood brotha going crazy 👀💰
# ------------------------------------------
# Tweet Text: @BlondeFoxy @DeoTasDevil *sends all the huggles*
# ------------------------------------------
# Tweet Text: @GodDamnGram @shannonmichele_ LOL they really don’t
# ------------------------------------------
# Tweet Text: Hello I’ll take one in every color thnx
# ------------------------------------------
# Tweet Text: This could be really sweet. Full stop.
# ------------------------------------------
# Tweet Text: @podcastbymata ✊️ you too buddy!
# ------------------------------------------
# Tweet Text: not w the chasing shit, with me or without me 💯
# ------------------------------------------
# Tweet Text: #QWP
# #TruebrotherhooD
# Let unite to show the world our pious relationship with mutual understanding &amp; care beyond th… https://t.co/wC9jrjn860
# ------------------------------------------
# Tweet Text: @sherryontopp what have u to say...? She made sure of all arrangements too.....she should be charged with murder...… https://t.co/IaXuzIyWy0
# ------------------------------------------
# Tweet Text: @netteebby16 @IanKatz23 @Dodgers LMK if you want his address so you can jump him. Also ask what channel the Yankee… https://t.co/8LFwGPITdS
# ------------------------------------------
# Tweet Text: When foreign 'do-gooders' do more harm than good in Liberia ! Let's eradicate thre #whitesaviour complex nd empower… https://t.co/AJ5OeiX18o
# ------------------------------------------
# Tweet Text: head bangin' like DUTDUTDUT
# ------------------------------------------
# Tweet Text: @RannaRoyalAnna Happy Birthday old balls!!
# ------------------------------------------
# Tweet Text: @MrDavidGP @VulnerableVete1 @Queen_of_Gif Splendid work: really important to treat the whole person.
# ------------------------------------------
# Tweet Text: @PJHughes45 Too awake. Brewers over RedSox?
# ------------------------------------------
# Tweet Text: i miss havin someone
# ------------------------------------------
# Tweet Text: Drunk ama fuck @ChuppaVGC been too long. What people wanna know?
# ------------------------------------------
# Tweet Text: i feel like you’re targeting me jeremy 🤣🤔😏😉
# ------------------------------------------
# Tweet Text: Proud of them dawgs 👏🏾👏🏾
# ------------------------------------------
# Tweet Text: Don't treat people as bad as they are, treat them as good as you are.
# ------------------------------------------
# Tweet Text: Her house flooded and I checked on her,
#
# Had classes with her but didn’t wanna approach like every typical nigga do
# ------------------------------------------
# Tweet Text: @BethMooreLPM @mrs_jrt Hello. 💓We are kindred spirits. That is all. https://t.co/qcXkvhvlRw
# ------------------------------------------
# Tweet Text: Rihanna turns down Super Bowl halftime show in support of Kaepernick, US Weekly reports  https://t.co/v49kuekKiN
# ------------------------------------------
# Tweet Text: I love my fans💘💓💞
# ------------------------------------------
# Tweet Text: @bud_cann Did she really say that? video?
# ------------------------------------------
# Tweet Text: @sligogaa any chance the intermediate final is been streamed? 🤞🏻
# ------------------------------------------
# Tweet Text: Me at work when my boss catches me not doing my job
# ------------------------------------------
# Tweet Text: @Londonbeloved makes me want to shave my head fr fr you look so elegant go girl🦋🦋🦋❤️🌻
# ------------------------------------------
# Tweet Text: We are back wordsbookstorecafe !
# Just in time for Halloween 🎃
#
# words ALOUD.
# a ghoulish Family Open Mic.
# Calling a… https://t.co/vIKAS15UOC
# ------------------------------------------
# Tweet Text: @Ahmed_4846 I've seen many posts saying Saudis don't murderer Saudis. Shall we forget 9/11/2001? Mama's assassinati… https://t.co/RvQbYJhAY5
# ------------------------------------------
# Tweet Text: Lol. He came prepared o. Both of you won jare 👏
# ------------------------------------------
# Tweet Text: Want to work in #Gurugram, HR? View our latest opening: https://t.co/k78RYY5TSH #Finance #Job #Jobs #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Ion know if ima whore myself out like dat 😂 Issa couple tho
# ------------------------------------------
# Tweet Text: @CornPuzzle Mother fuck. Just finished playing a game of 2k,saw the score and was feeling snarky.
#
# I've never had an original thought smh
# ------------------------------------------
# Tweet Text: @SteveChapman13 My excuse?  Just plain lazy.
# ------------------------------------------
# Tweet Text: some little girl at the game said “we learn this saying in fourth grade: girls go to college to get knowledge and b… https://t.co/UBo2U2WmmJ
# ------------------------------------------
# Tweet Text: @CNN It’s like they are flaunting being crazy now isn’t this particular joker up for re-election?
# ------------------------------------------
# Tweet Text: Only difference is niggas be whispering in front certain niggas lol hoes don’t care lol
# ------------------------------------------
# Tweet Text: Wack asf class of 2016 did it better gg
# ------------------------------------------
# Tweet Text: In two days I’ve finished Queen of the Trap Toledo and In Love with a Southside Nigga, now I’m on to pt.2. They’re… https://t.co/C57YAkmAY2
# ------------------------------------------
# Tweet Text: You were everything and more. One of my favorite shows of all time. Also, thank you for playing on your birthday… https://t.co/HliNxinVZG
# ------------------------------------------
# Tweet Text: A bit more...🤭 en The Broad Museum https://t.co/ExN8BMXOsn
# ------------------------------------------
# Tweet Text: Honestly I never thought I could feel like this for him, he’s honestly the best.💛
# ------------------------------------------
# Tweet Text: @MyOtterName 'christians'
# ------------------------------------------
# Tweet Text: I just need to go M.I.A for a while.
# ------------------------------------------
# Tweet Text: Idea for Halloween costume:
# - Green body paint
# - Yellow shirt
# - Red bandana
# - Red &amp; yellow boas
# - Hulk Hands
#
# Becom… https://t.co/oyylpgh1h4
# ------------------------------------------
# Tweet Text: Our team of #beauty lovers likes to make work fun. Are you ready to elevate your career? We have a wonderful openin… https://t.co/INIQhXUCL1
# ------------------------------------------
# Tweet Text: @lazsamuels @DarrylT13861086 @chelseahandler Ohh... so ....not only is HRC responsible for the #Benghazi4 so is Oba… https://t.co/kusIf4akPg
# ------------------------------------------
# Tweet Text: Omg! Traffic!!! 😜😜😜 @ Riverside, California https://t.co/PTL2sgDroi
# ------------------------------------------
# Tweet Text: Can you recommend anyone for this #job? Change Management - https://t.co/JTwWI8XXxx #internship #Noida, UP #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Where the parties at 👀
# ------------------------------------------
# Tweet Text: Join the ADTRAN, Inc. team! See our latest #job opening here: https://t.co/B6cLLuQb7D #internship #Hyderabad, Telangana #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: Love others even if they won’t give you the time of day.
# Love unconditionally 💗
# ------------------------------------------
# Tweet Text: @AlexGon61287322 Sure are. Just soggy.
# ------------------------------------------
# Tweet Text: No phone or anything just need to be to myself .
# ------------------------------------------
# Tweet Text: Putting @joshuamoore541 to work on my knee cap. _allhallows_tattooexpo @ Coeur d'Alene Casino Resort Hotel https://t.co/I3gQKfBsUm
# ------------------------------------------
# Tweet Text: So wait? Jared cannonier gonna make his middleweight debut on two weeks notice...
# ------------------------------------------
# Tweet Text: Grande.
# ------------------------------------------
# Tweet Text: Interested in a #job in #Bangalore? This could be a great fit: https://t.co/iQHlaWLnMy #Developer #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: https://t.co/OrRgW8Y8ue - 'Proving' him wrong is a race to the bottom
# ------------------------------------------
# Tweet Text: i had a nice time tonight😊
# ------------------------------------------
# Tweet Text: These girls are so amazing and involved tonight! I am so blessed to have got to meet them and spend the evening wit… https://t.co/Qznc64Vkre
# ------------------------------------------
# Tweet Text: clear sky -&gt; broken clouds
# temperature up 56°F -&gt; 57°F
# wind 9mph -&gt; 10mph
# ------------------------------------------
# Tweet Text: These type of comments also create a very unhealthy stigma about mental health in general, and anxiety in particular.
#
# Stop doing this.
# ------------------------------------------
# Tweet Text: crazy
# ------------------------------------------
# Tweet Text: The more I tell myself “it be like that sometimes” the better I feel 🤷🏻‍♀️
# ------------------------------------------
# Tweet Text: @Deeevine_ STRONG JAW ASS BABY 😂😂😂
# ------------------------------------------
# Tweet Text: A Phi Just Flicking @ Mr. G's https://t.co/Pt5tzTLxGy
# ------------------------------------------
# Tweet Text: @UPSHelp how did you “miss” me when no one ever rang my buzzer?? https://t.co/eXkP88jDTe
# ------------------------------------------
# Tweet Text: Be with someone who is proud to have you...
# ------------------------------------------
# Tweet Text: ... that the San Diego Gulls radio deal absolutely stinks. 1090/1700 is a bait and switch. 9/10 the Gulls broadcast… https://t.co/D2Hw6TPZPd
# ------------------------------------------
# Tweet Text: As soon as I can 🤞🏻
# ------------------------------------------
# Tweet Text: I’m so tired
# ------------------------------------------
# Tweet Text: @changlashish @smitaprakash Ass u me.
# ------------------------------------------
# Tweet Text: 💋✨- you look like your full of life and enjoyment 😭
# ------------------------------------------
# Tweet Text: Just tryna make up for the times when i ain’t have shit
# ------------------------------------------
# Tweet Text: I miss going out at night :/
# ------------------------------------------
# Tweet Text: @sajinaraii @9GAG That's absolutely right ☺️💞
# ------------------------------------------
# Tweet Text: I can accept failure.  Everyone fails at something.  But I can't accept not trying. - Michael Jordan #quote #SaturdayMotivation
# ------------------------------------------
# Tweet Text: Mainey
# ------------------------------------------
# Tweet Text: @aaasoff I live for your adventures. Be safe please!! I love and miss you&lt;3
# ------------------------------------------
# Tweet Text: Out now🔥🔥🔥
# Dope song from KD baddest act
# Banz - eruku flows 0.2
# https://t.co/2ZuotM7Sem https://t.co/vePH517oUs
# ------------------------------------------
# Tweet Text: superrrr
# ------------------------------------------
# Tweet Text: Despite Sebetic’s Vezina performance, the Phoenix fall to the Demon Deacs 2-1.
# ------------------------------------------
# Tweet Text: I hope my shit don’t get towed
# ------------------------------------------
# Tweet Text: If this ain’t the most blessed
# picture I’ve seen... https://t.co/cJICsCWTXD
# ------------------------------------------
# Tweet Text: Silly humans
# ------------------------------------------
# Tweet Text: @SweetDeeGh How was the journey
# ------------------------------------------
# Tweet Text: @_EQuiroz_ hey how is trump racist
# ------------------------------------------
# Tweet Text: My dogs name is Lola.
#
# We call her:
# Lo
# Lolo
# Lomo
# Lo mama
# Lolita
# Lolo
# Lubaby
# Lulu
# Lofla
# Loaf
# Fat girl
# ------------------------------------------
# Tweet Text: I just found out my 17 year old brother only drinks Mikes and Smirnoffs. Idk how to feel
# ------------------------------------------
# Tweet Text: Tomorrow is a new day I’m ready @Dodgers
# ------------------------------------------
# Tweet Text: @kill4ngel at least im in my uber x comin home from work n imma be able to just lay in bed wow bed
# ------------------------------------------
# Tweet Text: Awesome! The fact #ScreamingFirehawks are out there already means alot!
# ------------------------------------------
# Tweet Text: Now Playing Kappo Aka Yung Razah - Sun Of Man Hosted by DJ Flipcyide via @DatPiff https://t.co/e5FIERpAvZ https://t.co/bgAdq9IFNs
# ------------------------------------------
# Tweet Text: @bmp_online @SkodaIndia  i would like to take @yashkadamyk7 @Harshad88852391 @omkarw2419 @SahilNa66153414 for the… https://t.co/IF3TClDR7t
# ------------------------------------------
# Tweet Text: @NoMoreElitists They are all #INVADERS
# ------------------------------------------
# Tweet Text: @atDavidHoffman @rogertansey They made him; they enable him; they expand him. I have long said they should ignore t… https://t.co/XvClPUjRFC
# ------------------------------------------
# Tweet Text: hey boo
# ------------------------------------------
# Tweet Text: @PlacerSheriff @CHPAuburn @CHPValleyAirOps Thank you to you all!
# ------------------------------------------
# Tweet Text: WATTBA and it’s not even close
# ------------------------------------------
# Tweet Text: Public service announcement it’s WEIRD to hangout with high schoolers once you’ve graduated................ being o… https://t.co/m2bFeSAo0l
# ------------------------------------------
# Tweet Text: Twitter has no respect 😂
# ------------------------------------------
# Tweet Text: @suzguerr Do you mind passing the recipe... 🙄 lol
# ------------------------------------------
# Tweet Text: And you are one of the kindest! 💖
# ------------------------------------------
# Tweet Text: The stripper kept my Rosarito heads band wtf
# ------------------------------------------
# Tweet Text: 🎃☠️👻Beetlejuice Beetlejuice beetlejui- https://t.co/AebL8UiySv
# ------------------------------------------
# Tweet Text: Lmfaooooo sooooo where did everyone go
# ------------------------------------------
# Tweet Text: LONG DAY’S JOURNEY INTO NIGHT: At once insular and ever-expanding, tracking with the most intent and generous of ey… https://t.co/hpDlTQK045
# ------------------------------------------
# Tweet Text: Dear @Uber_India ur drivers denied services when I selected @Paytm payment option. Has happened more than 10 times… https://t.co/x8nEHbVzhn
# ------------------------------------------
# Tweet Text: We live to push another day 🙏
# Lord take control, we need all 3 today 💯
# #Amakhosi4Life
# @BulawayoChiefs https://t.co/Wko3fGtCa8
# ------------------------------------------
# Tweet Text: Definitely ain’t football
# ------------------------------------------
# Tweet Text: If I’m going to do this. I have to do it right.
# ------------------------------------------
# Tweet Text: Incredible game @eugenegenerals Sooooo close! And they played so well! Can’t wait for tomorrow night! #GensFam
# ------------------------------------------
# Tweet Text: As per a Washington Post report more than half of all the deaths while taking a Selfie happens in India.
# More than… https://t.co/7AQAMSgPOC
# ------------------------------------------
# Tweet Text: Them my brothers .. We just getting started 🤐
# ------------------------------------------
# Tweet Text: @ColinHollis2 @bitterasiandude I suspect they weren’t even filming us. Not even miked. Paul and I just improvised a movie to pass the time.
# ------------------------------------------
# Tweet Text: This is Overwhelming.#PiyushMishra
#
# https://t.co/J1qEQoVunT.
# ------------------------------------------
# Tweet Text: Playing tourist in Portland was so relaxing 😌 @ Portland Japanese Garden https://t.co/Ana1iF0ZWL
# ------------------------------------------
# Tweet Text: @jjtbyrne62 @chuckwoolery @BreitbartNews Wackadoodle!!
# ------------------------------------------
# Tweet Text: Drone shot from the gig I was doing of the Lake Merritt light festival with Community bridge video CB Smith-Dahl. I… https://t.co/Lrg4HU1mdn
# ------------------------------------------
# Tweet Text: You mean to tell me guys don’t do this??? Y’all missing out!!!
# ------------------------------------------
# Tweet Text: i have so many drafted tweets that i think should go viral cause i’m hilarious but i know no one would agree with me soooo
# ------------------------------------------
# Tweet Text: I aspire to have someone care about me this much
# ------------------------------------------
# Tweet Text: @jurzygl007 If it wasn’t I would have led this tweet with my laptop drowned in my backpac, duh
# ...
# ------------------------------------------
# Tweet Text: Serious accident in #Columbus on Dundee Ave at Hamilton Rd #traffic https://t.co/hylMo0WgFI
# ------------------------------------------
# Tweet Text: I Hate Being Up This Early Butttttttt I Always Seems To Have My Best Sessions Around This Time
# ------------------------------------------
# Tweet Text: @Jeremy_Danner @thefullpint Share your super cute pets as often as possible... but trying to get Gerber to recogniz… https://t.co/lfsSGTQcfQ
# ------------------------------------------
# Tweet Text: He’s still touching me *
# ------------------------------------------
# Tweet Text: @zemadtater imma claw my way out of this hell hole and come home, as soon as possible
# ------------------------------------------
# Tweet Text: #SaturdayMorningCruise With @Solapost NP: Sketchers - @Dusten_Truce @TylerRIDDIM
# ------------------------------------------
# Tweet Text: @candelario_50 Always🙏🏻
# ------------------------------------------
# Tweet Text: Spoiler alert: the 5 accounts that consistently like and retweet everything you post are all run by the same guy, a… https://t.co/41IkMuF7z2
# ------------------------------------------
# Tweet Text: goodnight https://t.co/F6JFtQZxXm
# ------------------------------------------
# Tweet Text: You laugh at me because I am different, I laugh at you because you are all the same. #ALDUBNationforDaddysGurl
# ------------------------------------------
# Tweet Text: @AnselLindner @IMmsGNU @francispouliot_ Gotcha "hard money" is short for "hard to inflate money"
#
# "Paper is povert… https://t.co/7mgd9RUG4F
# ------------------------------------------
# Tweet Text: My boss yelled at me today in front of all my coworkers for literally no reason !!! Let’s return this bread it wasn’t worth it
# ------------------------------------------
# Tweet Text: @TillerMiller_ Thaaaaaanks Tyyyyyyler 💖💖
# ------------------------------------------
# Tweet Text: Sai aure brother 😂🙌🏻
# ------------------------------------------
# Tweet Text: This will be the last time... the fucking last time I let someone in.
# ------------------------------------------
# Tweet Text: Rebiotix and Microbiome Insights Collaborate on a Microbiome IBD Tool for Clinical Development | Business Wire https://t.co/WcTrOP5lZB
# ------------------------------------------
# Tweet Text: @BreitbartNews Wow. She's hard to look at much less listen to. 😂 #TDS
# ------------------------------------------
# Tweet Text: I WONDER IF I CAN CHEW GUM NOW 😭😭😭
# ------------------------------------------
# Tweet Text: I pray that I never develop the “Men ain’t s***” mentality. Like I hear it and see it said often.
# ------------------------------------------
# Tweet Text: @bluemunia YEAH i haven't used it in awhile, a week or so after the release of the last monhun
# ------------------------------------------
# Tweet Text: @SenSchumer @realDonaldTrump Fascinating, right Uncle Chuck? https://t.co/OgfYfS5V0d
# ------------------------------------------
# Tweet Text: @HelenFathers At least another four years, @HelenFathers!!
# ------------------------------------------
# Tweet Text: Can you recommend anyone for this #job in #Ulaanbaatar, Ulaanbaatar? https://t.co/lyrCnmRTcf #CustomerService #Hiring #CareerArc
# ------------------------------------------
# Tweet Text: @24_tko @pistol_pete51 😂😂😂good thing we never did it huh?
# ------------------------------------------
# Tweet Text: Shower beers are underrated. Getting ready to go out with the guys? Shower beer. Long day at work? Shower beer. Hav… https://t.co/DoQFF0dldT
# ------------------------------------------
# Tweet Text: Head In The Clouds with @88rising
#
# Shots by @stephanietacy #atxconcert https://t.co/0HACKWdKLC
# ------------------------------------------
# Tweet Text: I wanna get drunk
# ------------------------------------------
# Tweet Text: I'm at The Reef in Managua https://t.co/vzDmdhvTTQ
# ------------------------------------------
# Tweet Text: @JuddApatow @realDonaldTrump @RockTheVote Judd, I was at Trump Rally in Mesa,AZ tonight. Multiple hundreds left 20… https://t.co/6wKUKvAYP0
# ------------------------------------------
# Tweet Text: Faces of Trump and his supporters (PHOTOS) https://t.co/wiKbZeTUdX
# ------------------------------------------
# Tweet Text: I hate super technical people who truly care about astrology. Motherfukas be like cusps aren’t real well someone to… https://t.co/N9tq8WRn17
# ------------------------------------------
# Tweet Text: I feel bad for her, but all actions have consequences.  Doing something clearly illegal, especially in a foreign co… https://t.co/yCRkJqsukF
# ------------------------------------------
# Tweet Text: @JeanMarcV @MaximusFelix @tedcruz @BetoORourke @Turnip2020 Yes, turnt up for @Turnip2020
# ------------------------------------------
# Tweet Text: @NancyMA47 @newtgingrich @David_Bossie SOROS has lots of money‼️
# ------------------------------------------
# Tweet Text: “WHAT AM I GONNA DO WITH A TITTY APPLE?!” LMAOOOOO
# ------------------------------------------
# Tweet Text: @ArianeAndrew Cameron, Hi, I Love You Very Much, How are you ever  since the days of #TonsOfFunk the #Funkdactyls  ?
# ------------------------------------------
# Tweet Text: So you Saucy Saucy
# ------------------------------------------
# Tweet Text: Gun rights are rights for all in the US. any person capable of owning a firearm legally should do so and exercise h… https://t.co/Z8gP9yV5Da
# ------------------------------------------
# Tweet Text: We did it! Submitted our video. Here is a bit of a sneak preview.
# I doubt we would be selected, but a girl can wish… https://t.co/AMkmJ7pmpc
# ------------------------------------------
# Tweet Text: It fucking irks me when they put the video out late as fuck
# ------------------------------------------
# Tweet Text: Interested in joining our growing Flex family in #Sriperumbudur, TN? We’re currently hiring for Engineer - Process!… https://t.co/E9vqSGsjiW
# ------------------------------------------
# Tweet Text: Night y’all &amp; stay safe💚💚💚💚💚💚💚💚💚
# ------------------------------------------
# Tweet Text: @1500ESPNJudd He wants to win. This team won’t win without him
# ------------------------------------------
# Tweet Text: Every end is d beginning of d new race https://t.co/3TPd1OK6Kq
# ------------------------------------------
# Tweet Text: Happy Birthday 🎂 🎂 @virendersehwag paji.. wo 1-2 six or maro gaane gatey gate 🤣😂 #VirenderSehwag #BCCI… https://t.co/1XHxY1IoVZ
# ------------------------------------------
# Tweet Text: Follow me on Instagram &amp; I’ll follow back https://t.co/lB3BG2TCOb
# ------------------------------------------
# Tweet Text: May God bless Afghanistan and peace prevails.✌🏻
# ------------------------------------------
# Tweet Text: Let's See How This Goes.....🤷🏽‍♀️
# ------------------------------------------
# Tweet Text: So grateful to @JackieWoodson and @rafaellopezart for sharing their creative processes and insights tonight. Please… https://t.co/6jg96pOdBq
# ------------------------------------------
# Tweet Text: @DodgerInsider We need to get the rakes out and hit!
# ------------------------------------------
# Tweet Text: @yungtreebranch Steph a lethal weapon because he can shoot the bloody piss out of the ball. GOAT shooter. However w… https://t.co/rPauBYGY6A
# ------------------------------------------
# Tweet Text: Did NADMO issue same statement when the vice president shared expired items?
#
# Can citizens also alert or report Vi… https://t.co/Q4nWl0aWxk
# ------------------------------------------
# Tweet Text: I can't even watch Sportscenter...frustration
# ------------------------------------------
# Tweet Text: @BKarbowski @marchimark I do fellow her and love her ❤😍😚
# ------------------------------------------
# Tweet Text: When you can’t go to the club cause you got skating, so you bring the club to skating
# ------------------------------------------
# Tweet Text: Some bar in Germany 🤷🏽‍♂️ https://t.co/0CUF8JOFM2
# ------------------------------------------
# Tweet Text: Well, 26 years old, 6 years of carreer, I think he can afford to have a car 😂
# ------------------------------------------
# Tweet Text: I have never found Chilima convincing but it's abit nonsensical to think that he didn't have a good interview simpl… https://t.co/gGUcQlleF5
# ------------------------------------------
# Tweet Text: Gimme a hit
# ------------------------------------------
# Tweet Text: @dinushhe Yeap tonight im starting it now
# ------------------------------------------
# Tweet Text: Rookie wey Dey give orders 🤣
# ------------------------------------------
# Tweet Text: I just realized I need to get her a collar and leash 🙄
# ------------------------------------------
# Tweet Text: I have the best mom in the entire world ❤️
# ------------------------------------------
# Tweet Text: Weak alibi.
# ------------------------------------------
# Tweet Text: @vivekagnihotri @arpit_bhargav25 SC Judgement not single religious community behind this permission. Respect till t… https://t.co/1ktmhDYwz6
# ------------------------------------------
# Tweet Text: I can't deal with this weather. I don't like the cold!😰
# ------------------------------------------
# Tweet Text: @khadijah104 I’m in Dallas it was raining all day
# ------------------------------------------
# Tweet Text: Not interested in a lot of shit .
# ------------------------------------------
# Tweet Text: Ooh Weller’s going to start suspecting Remi now... #Blindspot
# ------------------------------------------
# Tweet Text: i. cannot. wait.🤪🤪🤪 @kayla_hill33
# ------------------------------------------
# Tweet Text: @GOODMlAD @its_kaaatt They already did. I see this dumb ass picture down my TL at least 15 times a day with someone else quoting it
# ------------------------------------------
# Tweet Text: Gotta get this!!! @britneyspears #itsbritneybitch #babyonemoretimecollection #babyonemoretimecollectorsbundle… https://t.co/SM93Z913Zl
# ------------------------------------------
# Tweet Text: @ladygaga some new R&amp;B art I know you would love 🥂🎆
# ------------------------------------------
# Tweet Text: @mirandalt99 It looks good !!! Woohoo
# ------------------------------------------
# Tweet Text: I'm picking Michigan to beat Michigan State in East Lansing. Who you got? #GoBlue @RocketMortgage
# ------------------------------------------
# Tweet Text: I didn’t think I could love Lady Gaga more than I already did, but somehow I love her even more
# ------------------------------------------
# Tweet Text: She outta pocket 😂😭
# ------------------------------------------
# Tweet Text: I would ride into hell for jesus aguilar.
# ------------------------------------------
# Tweet Text: You the real king bro 👏🏻👏🏻🙏🏻
# ------------------------------------------
# Tweet Text: A HOT OLDER MALE JUST ASKED ME OUT
# ------------------------------------------
# Tweet Text: @faith_adetayo Hmmmm.... Sad reality
# ------------------------------------------
# Tweet Text: AYYYY TAMPA GETS RATCHETTTT 😛😛
# ------------------------------------------
# Tweet Text: Drow Ranger will be Rhi Rhi on my stream forever. #PlayArtifact
# ------------------------------------------
# Tweet Text: Good morning Nimaj https://t.co/H9L95iOuco
# ------------------------------------------
# Tweet Text: You know it’s a party when @Pitbull hits the stage! @ Foxtail SLS Las Vegas https://t.co/SImGNN1pz7
# ------------------------------------------
# Tweet Text: I hate listening to music when I don’t have top 10 songs I’m currently obsessed with
# ------------------------------------------
# Tweet Text: My man did it for Big SKUNK @malwill34
# ------------------------------------------
# Tweet Text: “Do not call nine one one” 🗣
# ------------------------------------------
# Tweet Text: @sir_phly @OhYeahItsG what is wrong with us 🤦🏾‍♀️
# ------------------------------------------
# Tweet Text: people are wild  😂
# ------------------------------------------
# Tweet Text: @ThatGirlLeigh I get what you’re saying. It’s a hard comparison but that’s why I made the poll! Lol
# ------------------------------------------
# Tweet Text: @KnickFilmSchool Y’all hate if y’all want that dude is proven Quality he just looks dumb ass shit
# ------------------------------------------
# Tweet Text: @parentlikeadad What?
# ------------------------------------------
# Tweet Text: Next weekend is going to be a ball. I will Be dead man walking. Nothing but beautiful black women and alcohol aka Heaven.
# ------------------------------------------
# Tweet Text: Still pursuing the same nigga who shitted on you? Girl yous a foo!
# ------------------------------------------
# Tweet Text: I wanna go see halloweeeeeeeen
# ------------------------------------------
# Tweet Text: @queenkim_nyakim is BEAUTIFUL please!!
# ------------------------------------------
# Tweet Text: girl... u have so much potential. what is going on
# ------------------------------------------
# Tweet Text: I'm upset
# ------------------------------------------
# Tweet Text: Winning at the Casino and treating yourself to champagne
# ------------------------------------------
# Tweet Text: temperature down 70°F -&gt; 65°F
# humidity down 37% -&gt; 32%
# wind 3mph -&gt; 2mph
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b8b4064eb3b6> in <module>()
#       9 http_resp = resp
#      10 tcp_connection = conn
# ---> 11 for line in http_resp.iter_lines():
#      12     try:
#      13         full_tweet = json.loads(line)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     787         pending = None
#     788
# --> 789         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     790
#     791             if pending is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     743             if hasattr(self.raw, 'stream'):
#     744                 try:
# --> 745                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     746                         yield chunk
#     747                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %%
ckey="iTrUDoKffZNLfSYvc9ctDXGJZ"
csecret="XEuXkw8AesuyxYaiPG7CSI1r0IhuXhcN8vvTYyimrCoAvMShU4"
atoken="1048005627816169473-5tJdLYafXOfCUaHWDFtcqjCvBRdU90"
asecret="iIQRVbZTN625Zn1xRPwDKkOH8Mk4xqrAEn8ICb39CTIeY"

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
class TweetsListener(StreamListener):
 
    def __init__(self, csocket):
        self.client_socket = csocket
 
    def on_data(self, data):
        try:
            print(data.split('\n'))
            self.client_socket.send(data)
            return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True




def sendData(c_socket):
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    twitter_stream = Stream(auth, TweetsListener(c_socket))
    twitter_stream.filter(track=['trump'])
    
    

s = socket.socket()     # Create a socket object
host = "127.0.0.1"      # Get local machine name
port = 5555      # Reserve a port for your service.
s.bind((host, port))    # Bind to the port

print("Listening on port: %s" % str(port))

s.listen(5)                 # Now wait for client connection.
c, addr = s.accept()        # Establish connection with client.

print( "Received request from: " + str( addr ) )

sendData( c )
